# %% [markdown]
# <div style='background-color:orange'>
# <a id='TableOfContents'></a>
#     <b><u><i><h1 style='text-align:center ; padding-top:5px'>
#         Table of Contents
#     </h1></i></u></b>
#     <li><a href='#imports'>Imports</a>
#     <li><a href='#initial'>Initial Setup</a>
#     <li><a href='#model'>Modeling</a>
#     <li><a href='#bestmodel'>Best Model(s)</a>
#     <li><a href='#misc'>Miscellaneous</a>
#     </li>
# </div>

# %% [markdown]
# <div style='background-color:orange'>
# <a id='imports'></a>
#     <b><u><i><h1 style='text-align:center ; padding-top:5px'>
#         Imports
#     </h1></i></u></b>
#     <li><a href='#TableOfContents'>Table of Contents</a>
#     </li>
# </div>

# %%
# Vectorization & Dataframe
import numpy as np
import pandas as pd

# Visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# Classification Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# Encoder
from sklearn.preprocessing import OrdinalEncoder

# Model metric evaluation
from sklearn.metrics import accuracy_score

# .py files
import wrangle as w

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div style='background-color:orange'>
# <a id='initial'></a>
#     <b><u><i><h1 style='text-align:center ; padding-top:5px'>
#         Initial Setup
#     </h1></i></u></b>
#     <li><a href='#TableOfContents'>Table of Contents</a>
#     </li>
# </div>

# %%
# Load up master dataset
master = w.wrangle()
master.shape
# Out:
# (14174, 132)

# %%
# Feature selection for modeling
crash_conditions_cols= [
    'weather_condition',
    'light_condition',
    'surface_condition',
    'contributing_factor_1',
    'contributing_factor_2',
    'contributing_factor_3',
    'possible_contributing_factor_1',
    'possible_contributing_factor_2',
    'other_factor',
    'intersection_related',
    'manner_of_collision',
    'object_struck',
    'roadway_alignment',
    'roadway_type'
]

# %%
# Add the risk_agg column
risk_list, risk_dict = w.risk_scores_iterate_columns(master, crash_conditions_cols)
master['agg_injury_risk'] = risk_list

# %%
# Append the new column to the feature selection list
crash_conditions_cols.append('agg_injury_risk')

# %%
# THIS IS OPTIONAL!!!
# It appears that this column alone performs better
crash_conditions_cols = ['agg_injury_risk']

# %%
# Encode feature selected columns
encoder = OrdinalEncoder()
for col in crash_conditions_cols:
    if master[col].dtype == 'object':
        encoded_col = encoder.fit_transform(master[[col]])
        master[col] = encoded_col

# %%
# Split the data
train, validate, test = w.split(master, stratify='person_injury_severity')
train.shape, validate.shape, test.shape
# Out:
# ((9924, 133), (2832, 133), (1418, 133))

# %%
# Create x/y for each split dataset
train_x = train[crash_conditions_cols]
train_y = train.person_injury_severity
validate_x = validate[crash_conditions_cols]
validate_y = validate.person_injury_severity
test_x = test[crash_conditions_cols]
test_y = test.person_injury_severity

# %% [markdown]
# <div style='background-color:orange'>
# <a id='model'></a>
#     <b><u><i><h1 style='text-align:center ; padding-top:5px'>
#         Models
#     </h1></i></u></b>
#     <li><a href='#TableOfContents'>Table of Contents</a>
#     <li><a href='#modelcreatedict'>Create Model Dictionary</a>
#     <li><a href='#modelbaseline'>Baseline</a>
#     <li><a href='#modeldtc'>DecisionTreeClassifier</a>
#     <li><a href='#modelrfc'>RandomForestClassifier</a>
#     <li><a href='#modelknn'>K-Nearest Neighbors</a>
#     <li><a href='#modellr'>Logistic Regression</a>
#     </li>
# </div>

# %% [markdown]
# <a id='modelcreatedict'></a>
# <h3><b><i>
#     Create Model Dictionary
# </i></b></h3>
# <li><a href='#model'>Models Top</a></li>

# %%
# Create base look of models_dict
models_dict = {
    'model_name' : [],
    'model_type' : [],
    'model_params' : [],
    'train_accuracy' : [],
    'validate_accuracy' : [],
    'accuracy_diff' : []
}

# %% [markdown]
# ---

# %% [markdown]
# <a id='modelbaseline'></a>
# <h3><b><i>
#     Baseline
# </i></b></h3>
# <li><a href='#model'>Models Top</a></li>

# %%
# Establish the ratio of the most common value
mode_value = train.person_injury_severity.mode()[0]
mode_total_train = (train.person_injury_severity == mode_value).sum()
mode_total_validate = (validate.person_injury_severity == mode_value).sum()
mode_total_test = (test.person_injury_severity == mode_value).sum()
mode_percent_train = mode_total_train / train.shape[0]
mode_percent_validate = mode_total_validate / validate.shape[0]
mode_percent_test = mode_total_test / test.shape[0]

# %%
# Append baseline to 'models_dict'
models_dict['model_name'].append('baseline')
models_dict['model_type'].append('baseline - mode')
models_dict['model_params'].append('none')
models_dict['train_accuracy'].append(f'{mode_percent_train:.3f}')
models_dict['validate_accuracy'].append(f'{mode_percent_validate:.3f}')
models_dict['accuracy_diff'].append(f'{mode_percent_validate - mode_percent_train:.3f}')

# %%
# Check out the 'models_dict'
pd.DataFrame(models_dict)
# Out:
#   model_name       model_type model_params train_accuracy validate_accuracy
# 0   baseline  baseline - mode         none          0.575             0.575  \
#
#   accuracy_diff
# 0         0.000

# %% [markdown]
# ---

# %% [markdown]
# <a id='modeldtc'></a>
# <h3><b><i>
#     DecisionTreeClassifier
# </i></b></h3>
# <li><a href='#model'>Models Top</a></li>

# %%
# Create generic DecisionTreeClassifer
for i in range(1, 11):
    model_name = f'dtc{i}'
    dtc = DecisionTreeClassifier(max_depth=i, random_state=1776)
    dtc.fit(train_x, train_y)
    train_score = dtc.score(train_x, train_y)
    val_score = dtc.score(validate_x, validate_y)
    diff_score = val_score - train_score
    models_dict['model_name'].append(model_name)
    models_dict['model_type'].append('Decision Tree Classifier')
    models_dict['model_params'].append(f'max_depth={i}, random_state=1776')
    models_dict['train_accuracy'].append(f'{train_score:.3f}')
    models_dict['validate_accuracy'].append(f'{val_score:.3f}')
    models_dict['accuracy_diff'].append(f'{diff_score:.3f}')

# %%
# Check out the 'models_dict'
pd.DataFrame(models_dict)
# Out:
#    model_name                model_type                     model_params
# 0    baseline           baseline - mode                             none  \
# 1        dtc1  Decision Tree Classifier   max_depth=1, random_state=1776
# 2        dtc2  Decision Tree Classifier   max_depth=2, random_state=1776
# 3        dtc3  Decision Tree Classifier   max_depth=3, random_state=1776
# 4        dtc4  Decision Tree Classifier   max_depth=4, random_state=1776
# 5        dtc5  Decision Tree Classifier   max_depth=5, random_state=1776
# 6        dtc6  Decision Tree Classifier   max_depth=6, random_state=1776
# 7        dtc7  Decision Tree Classifier   max_depth=7, random_state=1776
# 8        dtc8  Decision Tree Classifier   max_depth=8, random_state=1776
# 9        dtc9  Decision Tree Classifier   max_depth=9, random_state=1776
# 10      dtc10  Decision Tree Classifier  max_depth=10, random_state=1776
#
#    train_accuracy validate_accuracy accuracy_diff
# 0           0.575             0.575         0.000
# 1           0.575             0.575         0.000
# 2           0.590             0.590        -0.001
# 3           0.596             0.593        -0.003
# 4           0.597             0.591        -0.006
# 5           0.599             0.591        -0.008
# 6           0.603             0.587        -0.016
# 7           0.606             0.587        -0.019
# 8           0.611             0.587        -0.024
# 9           0.616             0.573        -0.042
# 10          0.621             0.583        -0.038

# %% [markdown]
# ---

# %% [markdown]
# <a id='modelrfc'></a>
# <h3><b><i>
#     RandomForestClassifier
# </i></b></h3>
# <li><a href='#model'>Models Top</a></li>

# %%
# Create generic RandomForestClassifer
for i in range(1, 11):
    model_name = f'rfc{i}'
    rfc = RandomForestClassifier(max_depth=i, random_state=1776)
    rfc.fit(train_x, train_y)
    train_score = rfc.score(train_x, train_y)
    val_score = rfc.score(validate_x, validate_y)
    diff_score = val_score - train_score
    models_dict['model_name'].append(model_name)
    models_dict['model_type'].append('Random Forest Classifier')
    models_dict['model_params'].append(f'max_depth={i}, random_state=1776')
    models_dict['train_accuracy'].append(f'{train_score:.3f}')
    models_dict['validate_accuracy'].append(f'{val_score:.3f}')
    models_dict['accuracy_diff'].append(f'{diff_score:.3f}')

# %%
# Check out the 'models_dict'
pd.DataFrame(models_dict)
# Out:
#    model_name                model_type                     model_params
# 0    baseline           baseline - mode                             none  \
# 1        dtc1  Decision Tree Classifier   max_depth=1, random_state=1776
# 2        dtc2  Decision Tree Classifier   max_depth=2, random_state=1776
# 3        dtc3  Decision Tree Classifier   max_depth=3, random_state=1776
# 4        dtc4  Decision Tree Classifier   max_depth=4, random_state=1776
# 5        dtc5  Decision Tree Classifier   max_depth=5, random_state=1776
# 6        dtc6  Decision Tree Classifier   max_depth=6, random_state=1776
# 7        dtc7  Decision Tree Classifier   max_depth=7, random_state=1776
# 8        dtc8  Decision Tree Classifier   max_depth=8, random_state=1776
# 9        dtc9  Decision Tree Classifier   max_depth=9, random_state=1776
# 10      dtc10  Decision Tree Classifier  max_depth=10, random_state=1776
# 11       rfc1  Random Forest Classifier   max_depth=1, random_state=1776
# 12       rfc2  Random Forest Classifier   max_depth=2, random_state=1776
# 13       rfc3  Random Forest Classifier   max_depth=3, random_state=1776
# 14       rfc4  Random Forest Classifier   max_depth=4, random_state=1776
# 15       rfc5  Random Forest Classifier   max_depth=5, random_state=1776
# 16       rfc6  Random Forest Classifier   max_depth=6, random_state=1776
# 17       rfc7  Random Forest Classifier   max_depth=7, random_state=1776
# 18       rfc8  Random Forest Classifier   max_depth=8, random_state=1776
# 19       rfc9  Random Forest Classifier   max_depth=9, random_state=1776
# 20      rfc10  Random Forest Classifier  max_depth=10, random_state=1776
#
#    train_accuracy validate_accuracy accuracy_diff
# 0           0.575             0.575         0.000
# 1           0.575             0.575         0.000
# 2           0.590             0.590        -0.001
# 3           0.596             0.593        -0.003
# 4           0.597             0.591        -0.006
# 5           0.599             0.591        -0.008
# 6           0.603             0.587        -0.016
# 7           0.606             0.587        -0.019
# 8           0.611             0.587        -0.024
# 9           0.616             0.573        -0.042
# 10          0.621             0.583        -0.038
# 11          0.591             0.588        -0.003
# 12          0.591             0.590        -0.001
# 13          0.596             0.591        -0.005
# 14          0.598             0.594        -0.005
# 15          0.599             0.595        -0.004
# 16          0.606             0.596        -0.010
# 17          0.613             0.593        -0.020
# 18          0.621             0.589        -0.032
# 19          0.632             0.587        -0.045
# 20          0.642             0.586        -0.056

# %% [markdown]
# ---

# %% [markdown]
# <a id='modelknn'></a>
# <h3><b><i>
#     K-Nearest Neighbors
# </i></b></h3>
# <li><a href='#model'>Models Top</a></li>

# %%
# Create generic K-Nearest Neighbors
for i in range(1, 11):
    model_name = f'knn{i}'
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(train_x, train_y)
    train_score = knn.score(train_x, train_y)
    val_score = knn.score(validate_x, validate_y)
    diff_score = val_score - train_score
    models_dict['model_name'].append(model_name)
    models_dict['model_type'].append('K-Nearest Neighbors')
    models_dict['model_params'].append(f'n_neighbors={i}')
    models_dict['train_accuracy'].append(f'{train_score:.3f}')
    models_dict['validate_accuracy'].append(f'{val_score:.3f}')
    models_dict['accuracy_diff'].append(f'{diff_score:.3f}')

# %%
# Check out the 'models_dict'
pd.DataFrame(models_dict)
# Out:
#    model_name                model_type                     model_params
# 0    baseline           baseline - mode                             none  \
# 1        dtc1  Decision Tree Classifier   max_depth=1, random_state=1776
# 2        dtc2  Decision Tree Classifier   max_depth=2, random_state=1776
# 3        dtc3  Decision Tree Classifier   max_depth=3, random_state=1776
# 4        dtc4  Decision Tree Classifier   max_depth=4, random_state=1776
# 5        dtc5  Decision Tree Classifier   max_depth=5, random_state=1776
# 6        dtc6  Decision Tree Classifier   max_depth=6, random_state=1776
# 7        dtc7  Decision Tree Classifier   max_depth=7, random_state=1776
# 8        dtc8  Decision Tree Classifier   max_depth=8, random_state=1776
# 9        dtc9  Decision Tree Classifier   max_depth=9, random_state=1776
# 10      dtc10  Decision Tree Classifier  max_depth=10, random_state=1776
# 11       rfc1  Random Forest Classifier   max_depth=1, random_state=1776
# 12       rfc2  Random Forest Classifier   max_depth=2, random_state=1776
# 13       rfc3  Random Forest Classifier   max_depth=3, random_state=1776
# 14       rfc4  Random Forest Classifier   max_depth=4, random_state=1776
# 15       rfc5  Random Forest Classifier   max_depth=5, random_state=1776
# 16       rfc6  Random Forest Classifier   max_depth=6, random_state=1776
# 17       rfc7  Random Forest Classifier   max_depth=7, random_state=1776
# 18       rfc8  Random Forest Classifier   max_depth=8, random_state=1776
# 19       rfc9  Random Forest Classifier   max_depth=9, random_state=1776
# 20      rfc10  Random Forest Classifier  max_depth=10, random_state=1776
# 21       knn1       K-Nearest Neighbors                    n_neighbors=1
# 22       knn2       K-Nearest Neighbors                    n_neighbors=2
# 23       knn3       K-Nearest Neighbors                    n_neighbors=3
# 24       knn4       K-Nearest Neighbors                    n_neighbors=4
# 25       knn5       K-Nearest Neighbors                    n_neighbors=5
# 26       knn6       K-Nearest Neighbors                    n_neighbors=6
# 27       knn7       K-Nearest Neighbors                    n_neighbors=7
# 28       knn8       K-Nearest Neighbors                    n_neighbors=8
# 29       knn9       K-Nearest Neighbors                    n_neighbors=9
# 30      knn10       K-Nearest Neighbors                   n_neighbors=10
#
#    train_accuracy validate_accuracy accuracy_diff
# 0           0.575             0.575         0.000
# 1           0.575             0.575         0.000
# 2           0.590             0.590        -0.001
# 3           0.596             0.593        -0.003
# 4           0.597             0.591        -0.006
# 5           0.599             0.591        -0.008
# 6           0.603             0.587        -0.016
# 7           0.606             0.587        -0.019
# 8           0.611             0.587        -0.024
# 9           0.616             0.573        -0.042
# 10          0.621             0.583        -0.038
# 11          0.591             0.588        -0.003
# 12          0.591             0.590        -0.001
# 13          0.596             0.591        -0.005
# 14          0.598             0.594        -0.005
# 15          0.599             0.595        -0.004
# 16          0.606             0.596        -0.010
# 17          0.613             0.593        -0.020
# 18          0.621             0.589        -0.032
# 19          0.632             0.587        -0.045
# 20          0.642             0.586        -0.056
# 21          0.853             0.471        -0.382
# 22          0.691             0.474        -0.217
# 23          0.682             0.513        -0.169
# 24          0.655             0.511        -0.144
# 25          0.649             0.532        -0.117
# 26          0.641             0.538        -0.103
# 27          0.638             0.554        -0.084
# 28          0.629             0.556        -0.073
# 29          0.628             0.560        -0.069
# 30          0.621             0.566        -0.054

# %% [markdown]
# ---

# %% [markdown]
# <a id='modellr'></a>
# <h3><b><i>
#     Logistic Regression
# </i></b></h3>
# <li><a href='#model'>Models Top</a></li>

# %%
# Create generic Logistic Regression
for i in range(1, 11):
    model_name = f'lr{i}'
    lr = LogisticRegression(solver='liblinear', intercept_scaling=i)
    lr.fit(train_x, train_y)
    train_score = lr.score(train_x, train_y)
    val_score = lr.score(validate_x, validate_y)
    diff_score = val_score - train_score
    models_dict['model_name'].append(model_name)
    models_dict['model_type'].append('Logistic Regression')
    models_dict['model_params'].append(f'solver=\'liblinear\', intercept_scaling{i}')
    models_dict['train_accuracy'].append(f'{train_score:.3f}')
    models_dict['validate_accuracy'].append(f'{val_score:.3f}')
    models_dict['accuracy_diff'].append(f'{diff_score:.3f}')

# %%
# Check out the 'models_dict'
pd.DataFrame(models_dict)
# Out:
#    model_name                model_type
# 0    baseline           baseline - mode  \
# 1        dtc1  Decision Tree Classifier
# 2        dtc2  Decision Tree Classifier
# 3        dtc3  Decision Tree Classifier
# 4        dtc4  Decision Tree Classifier
# 5        dtc5  Decision Tree Classifier
# 6        dtc6  Decision Tree Classifier
# 7        dtc7  Decision Tree Classifier
# 8        dtc8  Decision Tree Classifier
# 9        dtc9  Decision Tree Classifier
# 10      dtc10  Decision Tree Classifier
# 11       rfc1  Random Forest Classifier
# 12       rfc2  Random Forest Classifier
# 13       rfc3  Random Forest Classifier
# 14       rfc4  Random Forest Classifier
# 15       rfc5  Random Forest Classifier
# 16       rfc6  Random Forest Classifier
# 17       rfc7  Random Forest Classifier
# 18       rfc8  Random Forest Classifier
# 19       rfc9  Random Forest Classifier
# 20      rfc10  Random Forest Classifier
# 21       knn1       K-Nearest Neighbors
# 22       knn2       K-Nearest Neighbors
# 23       knn3       K-Nearest Neighbors
# 24       knn4       K-Nearest Neighbors
# 25       knn5       K-Nearest Neighbors
# 26       knn6       K-Nearest Neighbors
# 27       knn7       K-Nearest Neighbors
# 28       knn8       K-Nearest Neighbors
# 29       knn9       K-Nearest Neighbors
# 30      knn10       K-Nearest Neighbors
# 31        lr1       Logistic Regression
# 32        lr2       Logistic Regression
# 33        lr3       Logistic Regression
# 34        lr4       Logistic Regression
# 35        lr5       Logistic Regression
# 36        lr6       Logistic Regression
# 37        lr7       Logistic Regression
# 38        lr8       Logistic Regression
# 39        lr9       Logistic Regression
# 40       lr10       Logistic Regression
#
#                                model_params train_accuracy validate_accuracy
# 0                                      none          0.575             0.575  \
# 1            max_depth=1, random_state=1776          0.575             0.575
# 2            max_depth=2, random_state=1776          0.590             0.590
# 3            max_depth=3, random_state=1776          0.596             0.593
# 4            max_depth=4, random_state=1776          0.597             0.591
# 5            max_depth=5, random_state=1776          0.599             0.591
# 6            max_depth=6, random_state=1776          0.603             0.587
# 7            max_depth=7, random_state=1776          0.606             0.587
# 8            max_depth=8, random_state=1776          0.611             0.587
# 9            max_depth=9, random_state=1776          0.616             0.573
# 10          max_depth=10, random_state=1776          0.621             0.583
# 11           max_depth=1, random_state=1776          0.591             0.588
# 12           max_depth=2, random_state=1776          0.591             0.590
# 13           max_depth=3, random_state=1776          0.596             0.591
# 14           max_depth=4, random_state=1776          0.598             0.594
# 15           max_depth=5, random_state=1776          0.599             0.595
# 16           max_depth=6, random_state=1776          0.606             0.596
# 17           max_depth=7, random_state=1776          0.613             0.593
# 18           max_depth=8, random_state=1776          0.621             0.589
# 19           max_depth=9, random_state=1776          0.632             0.587
# 20          max_depth=10, random_state=1776          0.642             0.586
# 21                            n_neighbors=1          0.853             0.471
# 22                            n_neighbors=2          0.691             0.474
# 23                            n_neighbors=3          0.682             0.513
# 24                            n_neighbors=4          0.655             0.511
# 25                            n_neighbors=5          0.649             0.532
# 26                            n_neighbors=6          0.641             0.538
# 27                            n_neighbors=7          0.638             0.554
# 28                            n_neighbors=8          0.629             0.556
# 29                            n_neighbors=9          0.628             0.560
# 30                           n_neighbors=10          0.621             0.566
# 31   solver='liblinear', intercept_scaling1          0.575             0.575
# 32   solver='liblinear', intercept_scaling2          0.575             0.575
# 33   solver='liblinear', intercept_scaling3          0.575             0.575
# 34   solver='liblinear', intercept_scaling4          0.575             0.575
# 35   solver='liblinear', intercept_scaling5          0.575             0.575
# 36   solver='liblinear', intercept_scaling6          0.575             0.575
# 37   solver='liblinear', intercept_scaling7          0.575             0.575
# 38   solver='liblinear', intercept_scaling8          0.575             0.575
# 39   solver='liblinear', intercept_scaling9          0.575             0.575
# 40  solver='liblinear', intercept_scaling10          0.575             0.575
#
#    accuracy_diff
# 0          0.000
# 1          0.000
# 2         -0.001
# 3         -0.003
# 4         -0.006
# 5         -0.008
# 6         -0.016
# 7         -0.019
# 8         -0.024
# 9         -0.042
# 10        -0.038
# 11        -0.003
# 12        -0.001
# 13        -0.005
# 14        -0.005
# 15        -0.004
# 16        -0.010
# 17        -0.020
# 18        -0.032
# 19        -0.045
# 20        -0.056
# 21        -0.382
# 22        -0.217
# 23        -0.169
# 24        -0.144
# 25        -0.117
# 26        -0.103
# 27        -0.084
# 28        -0.073
# 29        -0.069
# 30        -0.054
# 31         0.000
# 32         0.000
# 33         0.000
# 34         0.000
# 35         0.000
# 36         0.000
# 37         0.000
# 38         0.000
# 39         0.000
# 40         0.000

# %% [markdown]
# rfc5 appears to perform the best

# %% [markdown]
# <div style='background-color:orange'>
# <a id='bestmodel'></a>
#     <b><u><i><h1 style='text-align:center ; padding-top:5px'>
#         Best Model(s)
#     </h1></i></u></b>
#     <li><a href='#TableOfContents'>Table of Contents</a>
#     </li>
# </div>

# %%
# Create best_models_dict
best_models_dict = {
    'model_name' : ['baseline'],
    'model_type' : ['baseline - mode'],
    'model_params' : ['none'],
    'train_accuracy' : [f'{mode_percent_train:.3f}'],
    'validate_accuracy' : [f'{mode_percent_validate:.3f}'],
    'test_accuracy' : [f'{mode_percent_test:.3f}']
}

# %%
# Recreate rfc5 and test it
rfc = RandomForestClassifier(max_depth=5, random_state=1776)
rfc.fit(train_x, train_y)
train_score = rfc.score(train_x, train_y)
val_score = rfc.score(validate_x, validate_y)
test_score = rfc.score(test_x, test_y)
best_models_dict['model_name'].append('rfc5')
best_models_dict['model_type'].append('Random Forest Classifier')
best_models_dict['model_params'].append(f'max_depth=5, random_state=1776')
best_models_dict['train_accuracy'].append(f'{train_score:.3f}')
best_models_dict['validate_accuracy'].append(f'{val_score:.3f}')
best_models_dict['test_accuracy'].append(f'{test_score:.3f}')

# %%
# Check out the 'models_dict'
pd.DataFrame(best_models_dict)
# Out:
#   model_name                model_type                    model_params
# 0   baseline           baseline - mode                            none  \
# 1       rfc5  Random Forest Classifier  max_depth=5, random_state=1776
#
#   train_accuracy validate_accuracy test_accuracy
# 0          0.575             0.575         0.575
# 1          0.599             0.595         0.591

# %% [markdown]
# <div style='background-color:orange'>
# <a id='misc'></a>
#     <b><u><i><h1 style='text-align:center ; padding-top:5px'>
#         Miscellaneous
#     </h1></i></u></b>
#     <li><a href='#TableOfContents'>Table of Contents</a>
#     </li>
# </div>
