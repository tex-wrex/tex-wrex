# %%
import numpy as np
import matplotlib as plt
import pandas as pd 
import re

# %%
df = pd.read_csv('person_data_info.csv')

# %%
df.isin(['no data']).sum()
# Out:
# crash_id                            0
# person_age                        335
# charge                              9
# person_ethnicity                   50
# financial_responsibility_type    4641
# crash_date                          0
# day_of_week                         0
# person_gender                       0
# person_helmet                       0
# driver_license_class               87
# driver_license_endorsements        36
# driver_drug_test_result             0
# driver_license_state              618
# driver_license_type                87
# person_injury_severity              0
# dtype: int64

# %%
for cols in df.columns:
    if df[cols].dtype == 'object':
        df[cols] = df[cols].str.lower()
        df[cols] = df[cols].replace(to_replace=re.compile(r'.*no\s*data.*', re.IGNORECASE), value='no data', regex=True).replace(to_replace= '')
df.head()
# Out:
#    crash_id person_age                                             charge
# 0  16189632         37                 operate unregistered motor vehicle  \
# 1  16203470         30                               no class "m" license
# 2  16191458         20  accident involving damage to vehicle>=$200/ fs...
# 3  16192023         21                                         no charges
# 4  16196720         18                     no driver license no insurance
#
#   person_ethnicity     financial_responsibility_type  crash_date day_of_week
# 0        w - white                           no data  2018-01-01      monday  \
# 1     h - hispanic  2 - proof of liability insurance  2018-01-04    thursday
# 2        w - white  2 - proof of liability insurance  2018-01-05      friday
# 3        w - white  2 - proof of liability insurance  2018-01-05      friday
# 4     h - hispanic                           no data  2018-01-05      friday
#
#   person_gender          person_helmet driver_license_class
# 0      1 - male           1 - not worn          c - class c  \
# 1      1 - male  3 - worn, not damaged          c - class c
# 2      1 - male   99 - unknown if worn          c - class c
# 3      1 - male      2 - worn, damaged          c - class c
# 4      1 - male           1 - not worn       5 - unlicensed
#
#   driver_license_endorsements driver_drug_test_result driver_license_state
# 0                        none     97 - not applicable           tx - texas  \
# 1                        none     97 - not applicable           tx - texas
# 2                        none     97 - not applicable           tx - texas
# 3                        none     97 - not applicable           tx - texas
# 4                  unlicensed     97 - not applicable           tx - texas
#
#   driver_license_type        person_injury_severity
# 0  1 - driver license  a - suspected serious injury
# 1  1 - driver license           c - possible injury
# 2  1 - driver license                  99 - unknown
# 3  1 - driver license  a - suspected serious injury
# 4         4 - id card    b - suspected minor injury

# %%
df[(df.driver_license_class == 'cm - class c and m') & (df.driver_license_endorsements == 'none')].head(10)
# Out:
#     crash_id person_age        charge person_ethnicity
# 5   16189103         28    no charges        w - white  \
# 10  16211875         57    no charges        w - white
# 11  16204997         18  unsafe speed     h - hispanic
# 13  16978915         48    no charges     h - hispanic
# 15  16193829         47    no charges     h - hispanic
# 18  16190900         41    no charges        w - white
# 19  16194513         66    no charges        w - white
# 20  16194515         23    no charges        w - white
# 21  16195540         33    no charges        w - white
# 26  16192883         22    no charges        w - white
#
#        financial_responsibility_type  crash_date day_of_week person_gender
# 5   2 - proof of liability insurance  2018-01-06    saturday      1 - male  \
# 10  2 - proof of liability insurance  2018-01-06    saturday      1 - male
# 11  2 - proof of liability insurance  2018-01-07      sunday      1 - male
# 13  2 - proof of liability insurance  2018-01-07      sunday      1 - male
# 15                           no data  2018-01-08      monday      1 - male
# 18  2 - proof of liability insurance  2018-01-09     tuesday      1 - male
# 19  2 - proof of liability insurance  2018-01-09     tuesday      1 - male
# 20                           no data  2018-01-09     tuesday      1 - male
# 21    1 - liability insurance policy  2018-01-09     tuesday      1 - male
# 26    1 - liability insurance policy  2018-01-10   wednesday      1 - male
#
#             person_helmet driver_license_class driver_license_endorsements
# 5   3 - worn, not damaged   cm - class c and m                        none  \
# 10  3 - worn, not damaged   cm - class c and m                        none
# 11   4 - worn, unk damage   cm - class c and m                        none
# 13      2 - worn, damaged   cm - class c and m                        none
# 15  3 - worn, not damaged   cm - class c and m                        none
# 18      2 - worn, damaged   cm - class c and m                        none
# 19           1 - not worn   cm - class c and m                        none
# 20           1 - not worn   cm - class c and m                        none
# 21      2 - worn, damaged   cm - class c and m                        none
# 26      2 - worn, damaged   cm - class c and m                        none
#
#    driver_drug_test_result driver_license_state driver_license_type
# 5      97 - not applicable           tx - texas  1 - driver license  \
# 10     97 - not applicable           tx - texas  1 - driver license
# 11     97 - not applicable           tx - texas  1 - driver license
# 13            2 - negative           tx - texas  1 - driver license
# 15     97 - not applicable           tx - texas  1 - driver license
# 18     97 - not applicable           tx - texas  1 - driver license
# 19     97 - not applicable           tx - texas  1 - driver license
# 20     97 - not applicable           tx - texas  1 - driver license
# 21     97 - not applicable           tx - texas  1 - driver license
# 26            2 - negative           tx - texas  1 - driver license
#
#         person_injury_severity
# 5   b - suspected minor injury
# 10             n - not injured
# 11  b - suspected minor injury
# 13            k - fatal injury
# 15             n - not injured
# 18            k - fatal injury
# 19  b - suspected minor injury
# 20  b - suspected minor injury
# 21  b - suspected minor injury
# 26            k - fatal injury

# %%
((df.driver_license_endorsements == 'none').sum()/ len(df)) * 100
# Out:
# 82.60929337365961

# %%
# here is where all the driver_license_class values are stored with  there is a m in there 
df.loc[df['driver_license_class'].str.contains('m'), 'driver_license_endorsements'] = 'm'
df.loc[df['driver_license_class'].str.contains('c - class c'), 'driver_license_endorsements'] = 'c'

# %%
((df.driver_license_endorsements == 'none').sum()/ len(df)) * 100
# Out:
# 6.770690129227386

# %% [markdown]
#     We managed to get our none values from 83 % down to just 7 %

# %%
df.rename(columns= {'driver_license_endorsements': 'has_motocycle_endorsment'}, inplace=True)

# %%
df[df.charge.str.contains('none')].head()
# Out:
#       crash_id person_age charge person_ethnicity
# 154   16278379         35   none     99 - unknown  \
# 506   16464871         56   none        w - white
# 903   16668065         60   none        w - white
# 1127  16854825         29   none        w - white
# 1205  16930095         36   none        w - white
#
#          financial_responsibility_type  crash_date day_of_week person_gender
# 154   2 - proof of liability insurance  2018-03-03    saturday      1 - male  \
# 506   2 - proof of liability insurance  2018-06-12     tuesday      1 - male
# 903   2 - proof of liability insurance  2018-10-05      friday    2 - female
# 1127                           no data  2019-01-16   wednesday      1 - male
# 1205  2 - proof of liability insurance  2019-02-22      friday      1 - male
#
#               person_helmet     driver_license_class has_motocycle_endorsment
# 154   3 - worn, not damaged              c - class c                        c  \
# 506    4 - worn, unk damage              c - class c                        c
# 903            1 - not worn       cm - class c and m                        m
# 1127   99 - unknown if worn  98 - other/out of state                     none
# 1205      2 - worn, damaged       cm - class c and m                        m
#
#      driver_drug_test_result driver_license_state driver_license_type
# 154      97 - not applicable           tx - texas  1 - driver license  \
# 506      97 - not applicable           tx - texas  1 - driver license
# 903      97 - not applicable           tx - texas  1 - driver license
# 1127     97 - not applicable        va - virginia  1 - driver license
# 1205     97 - not applicable           tx - texas  1 - driver license
#
#             person_injury_severity
# 154     b - suspected minor injury
# 506   a - suspected serious injury
# 903     b - suspected minor injury
# 1127  a - suspected serious injury
# 1205  a - suspected serious injury

# %%
df.financial_responsibility_type.value_counts()
# Out:
# financial_responsibility_type
# 2 - proof of liability insurance               7272
# no data                                        4641
# 1 - liability insurance policy                 2574
# 7 - certificate of self-insurance                25
# 3 - insurance binder                             25
# 5 - certificate of deposit with comptroller       7
# 4 - surety bond                                   4
# Name: count, dtype: int64

# %%
df.loc[(df['charge'] == 'none') & (df['financial_responsibility_type'] == 'no data'), 'financial_responsibility_type'] = '2 - proof of liability insurance'

# %%
df.financial_responsibility_type.value_counts()
# Out:
# financial_responsibility_type
# 2 - proof of liability insurance               7282
# no data                                        4631
# 1 - liability insurance policy                 2574
# 7 - certificate of self-insurance                25
# 3 - insurance binder                             25
# 5 - certificate of deposit with comptroller       7
# 4 - surety bond                                   4
# Name: count, dtype: int64

# %%
df[df.financial_responsibility_type == 'no data']
# Out:
#        crash_id person_age                                             charge
# 0      16189632         37                 operate unregistered motor vehicle  \
# 4      16196720         18                     no driver license no insurance
# 7      16196075         39                                         no charges
# 8      16198730    no data                                         no charges
# 12     16212108    no data                                         no charges
# ...         ...        ...                                                ...
# 14536  19322334         26  fail to drive in single lane, fail to maintain...
# 14537  19320049         44                                         no charges
# 14542  19319568         65                                         no charges
# 14544  19323296         33                                         no charges
# 14545  19327850         35                                         no charges
#
#       person_ethnicity financial_responsibility_type  crash_date day_of_week
# 0            w - white                       no data  2018-01-01      monday  \
# 4         h - hispanic                       no data  2018-01-05      friday
# 7         h - hispanic                       no data  2018-01-06    saturday
# 8         99 - unknown                       no data  2018-01-06    saturday
# 12           b - black                       no data  2018-01-07      sunday
# ...                ...                           ...         ...         ...
# 14536        b - black                       no data  2022-12-27     tuesday
# 14537        w - white                       no data  2022-12-28   wednesday
# 14542        w - white                       no data  2022-12-31    saturday
# 14544        w - white                       no data  2022-12-31    saturday
# 14545        w - white                       no data  2022-12-31    saturday
#
#       person_gender         person_helmet driver_license_class
# 0          1 - male          1 - not worn          c - class c  \
# 4          1 - male          1 - not worn       5 - unlicensed
# 7          1 - male          1 - not worn          c - class c
# 8      99 - unknown  99 - unknown if worn         99 - unknown
# 12         1 - male          1 - not worn         99 - unknown
# ...             ...                   ...                  ...
# 14536      1 - male     2 - worn, damaged          c - class c
# 14537      1 - male          1 - not worn          c - class c
# 14542      1 - male          1 - not worn   cm - class c and m
# 14544      1 - male          1 - not worn   cm - class c and m
# 14545      1 - male  4 - worn, unk damage   cm - class c and m
#
#       has_motocycle_endorsment driver_drug_test_result driver_license_state
# 0                            c     97 - not applicable           tx - texas  \
# 4                   unlicensed     97 - not applicable           tx - texas
# 7                            c     97 - not applicable           tx - texas
# 8                      unknown     97 - not applicable         un - unknown
# 12                     unknown     97 - not applicable         un - unknown
# ...                        ...                     ...                  ...
# 14536                        c     97 - not applicable           tx - texas
# 14537                        c     97 - not applicable           tx - texas
# 14542                        m            99 - unknown           tx - texas
# 14544                        m     97 - not applicable           tx - texas
# 14545                        m     97 - not applicable           tx - texas
#
#       driver_license_type        person_injury_severity
# 0      1 - driver license  a - suspected serious injury
# 4             4 - id card    b - suspected minor injury
# 7      1 - driver license  a - suspected serious injury
# 8            99 - unknown                  99 - unknown
# 12           99 - unknown                  99 - unknown
# ...                   ...                           ...
# 14536  1 - driver license    b - suspected minor injury
# 14537  1 - driver license  a - suspected serious injury
# 14542  1 - driver license              k - fatal injury
# 14544  1 - driver license  a - suspected serious injury
# 14545  1 - driver license  a - suspected serious injury
#
# [4631 rows x 15 columns]

# %%
df.isin(['no data']).sum()
# Out:
# crash_id                            0
# person_age                        335
# charge                              9
# person_ethnicity                   50
# financial_responsibility_type    4631
# crash_date                          0
# day_of_week                         0
# person_gender                       0
# person_helmet                       0
# driver_license_class               87
# has_motocycle_endorsment           36
# driver_drug_test_result             0
# driver_license_state              618
# driver_license_type                87
# person_injury_severity              0
# dtype: int64

# %% [markdown]
# ## For the sake of time and getting an mvp i am going to drop financial_responsibility_type column

# %%
df.drop(columns='financial_responsibility_type', inplace=True)

# %%
(df.isin(['no data']).sum() /len(df)) * 100
# Out:
# crash_id                    0.000000
# person_age                  2.302722
# charge                      0.061864
# person_ethnicity            0.343690
# crash_date                  0.000000
# day_of_week                 0.000000
# person_gender               0.000000
# person_helmet               0.000000
# driver_license_class        0.598020
# has_motocycle_endorsment    0.247457
# driver_drug_test_result     0.000000
# driver_license_state        4.248007
# driver_license_type         0.598020
# person_injury_severity      0.000000
# dtype: float64

# %%
(df.isin(['none']).sum() /len(df)) * 100
# Out:
# crash_id                    0.000000
# person_age                  0.000000
# charge                      0.233709
# person_ethnicity            0.000000
# crash_date                  0.000000
# day_of_week                 0.000000
# person_gender               0.000000
# person_helmet               0.000000
# driver_license_class        0.000000
# has_motocycle_endorsment    6.770690
# driver_drug_test_result     0.000000
# driver_license_state        0.000000
# driver_license_type         0.000000
# person_injury_severity      0.000000
# dtype: float64

# %% [markdown]
#     We are currently below 5 percent on the no data in the columns. I think we can work with the data frame with that much data.

# %%
df.loc[(df.charge == 'no charges') & (df.has_motocycle_endorsment == 'none'), 'has_motocycle_endorsment'] = 'm'

# %%
(df.isin(['none']).sum() /len(df)) * 100
# Out:
# crash_id                    0.000000
# person_age                  0.000000
# charge                      0.233709
# person_ethnicity            0.000000
# crash_date                  0.000000
# day_of_week                 0.000000
# person_gender               0.000000
# person_helmet               0.000000
# driver_license_class        0.000000
# has_motocycle_endorsment    1.800935
# driver_drug_test_result     0.000000
# driver_license_state        0.000000
# driver_license_type         0.000000
# person_injury_severity      0.000000
# dtype: float64

# %%
df.loc[(df.has_motocycle_endorsment == 'm'), 'has_motocycle_endorsment'] = 1
df.loc[(df.has_motocycle_endorsment != 'm'), 'has_motocycle_endorsment'] = 0

# %%
df.head()
# Out:
#    crash_id person_age                                             charge
# 0  16189632         37                 operate unregistered motor vehicle  \
# 1  16203470         30                               no class "m" license
# 2  16191458         20  accident involving damage to vehicle>=$200/ fs...
# 3  16192023         21                                         no charges
# 4  16196720         18                     no driver license no insurance
#
#   person_ethnicity  crash_date day_of_week person_gender
# 0        w - white  2018-01-01      monday      1 - male  \
# 1     h - hispanic  2018-01-04    thursday      1 - male
# 2        w - white  2018-01-05      friday      1 - male
# 3        w - white  2018-01-05      friday      1 - male
# 4     h - hispanic  2018-01-05      friday      1 - male
#
#            person_helmet driver_license_class has_motocycle_endorsment
# 0           1 - not worn          c - class c                        0  \
# 1  3 - worn, not damaged          c - class c                        0
# 2   99 - unknown if worn          c - class c                        0
# 3      2 - worn, damaged          c - class c                        0
# 4           1 - not worn       5 - unlicensed                        0
#
#   driver_drug_test_result driver_license_state driver_license_type
# 0     97 - not applicable           tx - texas  1 - driver license  \
# 1     97 - not applicable           tx - texas  1 - driver license
# 2     97 - not applicable           tx - texas  1 - driver license
# 3     97 - not applicable           tx - texas  1 - driver license
# 4     97 - not applicable           tx - texas         4 - id card
#
#          person_injury_severity
# 0  a - suspected serious injury
# 1           c - possible injury
# 2                  99 - unknown
# 3  a - suspected serious injury
# 4    b - suspected minor injury

# %%
# df[(df.charge == 'no charges') & (df.has_motocycle_endorsment == 'none')]['has_motocycle_endorsment'] = 'm'

# %% [markdown]
#     Sicne we are only looking at information that is collect at the begining if the insurane claim processess we are going to drop some information that we cannot collect in that intake form.

# %%
df.drop(columns='driver_drug_test_result', inplace=True)

# %%
df.head()
# Out:
#    crash_id person_age                                             charge
# 0  16189632         37                 operate unregistered motor vehicle  \
# 1  16203470         30                               no class "m" license
# 2  16191458         20  accident involving damage to vehicle>=$200/ fs...
# 3  16192023         21                                         no charges
# 4  16196720         18                     no driver license no insurance
#
#   person_ethnicity  crash_date day_of_week person_gender
# 0        w - white  2018-01-01      monday      1 - male  \
# 1     h - hispanic  2018-01-04    thursday      1 - male
# 2        w - white  2018-01-05      friday      1 - male
# 3        w - white  2018-01-05      friday      1 - male
# 4     h - hispanic  2018-01-05      friday      1 - male
#
#            person_helmet driver_license_class has_motocycle_endorsment
# 0           1 - not worn          c - class c                        0  \
# 1  3 - worn, not damaged          c - class c                        0
# 2   99 - unknown if worn          c - class c                        0
# 3      2 - worn, damaged          c - class c                        0
# 4           1 - not worn       5 - unlicensed                        0
#
#   driver_license_state driver_license_type        person_injury_severity
# 0           tx - texas  1 - driver license  a - suspected serious injury
# 1           tx - texas  1 - driver license           c - possible injury
# 2           tx - texas  1 - driver license                  99 - unknown
# 3           tx - texas  1 - driver license  a - suspected serious injury
# 4           tx - texas         4 - id card    b - suspected minor injury

# %%
# Here I am check to see if there is a driver license class that has a motocycle endorsment is accuratly reflected in the has_motocycle_endorsment column. 
df.loc[df.driver_license_class.str.contains('m') & (df.has_motocycle_endorsment == 0), 'has_motocycle_endorsment'] = 1

# %%
# checking the value counts for motorcycle endorsment
df.has_motocycle_endorsment.value_counts()
# Out:
# has_motocycle_endorsment
# 0    8303
# 1    6245
# Name: count, dtype: int64

# %%
(df.isin(['none'])).sum()
# Out:
# crash_id                     0
# person_age                   0
# charge                      34
# person_ethnicity             0
# crash_date                   0
# day_of_week                  0
# person_gender                0
# person_helmet                0
# driver_license_class         0
# has_motocycle_endorsment     0
# driver_license_state         0
# driver_license_type          0
# person_injury_severity       0
# dtype: int64

# %% [markdown]
#     Here we are checking which columns has none as a value and charge is the only one that has one now well check for no data.

# %%
df.isin(['no data']).sum()
# Out:
# crash_id                      0
# person_age                  335
# charge                        9
# person_ethnicity             50
# crash_date                    0
# day_of_week                   0
# person_gender                 0
# person_helmet                 0
# driver_license_class         87
# has_motocycle_endorsment      0
# driver_license_state        618
# driver_license_type          87
# person_injury_severity        0
# dtype: int64

# %%
# lets investigate the age columns
df[df.person_ethnicity == 'no data']= np.nan

# %%
df.person_age.isna().sum()
# Out:
# 50

# %%
df.iloc[12797].charge
# Out:
# nan

# %%
df.isin(['no data']).sum()
# Out:
# crash_id                      0
# person_age                  323
# charge                        9
# person_ethnicity              0
# crash_date                    0
# day_of_week                   0
# person_gender                 0
# person_helmet                 0
# driver_license_class         81
# has_motocycle_endorsment      0
# driver_license_state        610
# driver_license_type          81
# person_injury_severity        0
# dtype: int64

# %%
no_data_list = list()
for cols in df.columns:
    if df[cols].isin(['no data']).sum() > 0:
        no_data_list.append(cols)

# %%
df[no_data_list]
# Out:
#       person_age                                             charge
# 0             37                 operate unregistered motor vehicle  \
# 1             30                               no class "m" license
# 2             20  accident involving damage to vehicle>=$200/ fs...
# 3             21                                         no charges
# 4             18                     no driver license no insurance
# ...          ...                                                ...
# 14543         49                                         no charges
# 14544         33                                         no charges
# 14545         35                                         no charges
# 14546         42                       fail to drive in single lane
# 14547         49                                         no charges
#
#       driver_license_class driver_license_state driver_license_type
# 0              c - class c           tx - texas  1 - driver license
# 1              c - class c           tx - texas  1 - driver license
# 2              c - class c           tx - texas  1 - driver license
# 3              c - class c           tx - texas  1 - driver license
# 4           5 - unlicensed           tx - texas         4 - id card
# ...                    ...                  ...                 ...
# 14543   cm - class c and m           tx - texas  1 - driver license
# 14544   cm - class c and m           tx - texas  1 - driver license
# 14545   cm - class c and m           tx - texas  1 - driver license
# 14546   cm - class c and m           tx - texas  1 - driver license
# 14547   cm - class c and m           tx - texas  1 - driver license
#
# [14548 rows x 5 columns]

# %%
df[df[no_data_list] == 'no data']= np.nan

# %%
df.isin(['no data']).sum()
# Out:
# crash_id                    0
# person_age                  0
# charge                      0
# person_ethnicity            0
# crash_date                  0
# day_of_week                 0
# person_gender               0
# person_helmet               0
# driver_license_class        0
# has_motocycle_endorsment    0
# driver_license_state        0
# driver_license_type         0
# person_injury_severity      0
# dtype: int64

# %%
df.isin(['none']).sum()
# Out:
# crash_id                     0
# person_age                   0
# charge                      34
# person_ethnicity             0
# crash_date                   0
# day_of_week                  0
# person_gender                0
# person_helmet                0
# driver_license_class         0
# has_motocycle_endorsment     0
# driver_license_state         0
# driver_license_type          0
# person_injury_severity       0
# dtype: int64

# %%
none_list = list()
for cols in df.columns:
    if df[cols].isin(['none']).sum() > 0:
        none_list.append(cols)
df[df[none_list] == 'none']= np.nan

# %%
df.isin(['none']).sum()
# Out:
# crash_id                    0
# person_age                  0
# charge                      0
# person_ethnicity            0
# crash_date                  0
# day_of_week                 0
# person_gender               0
# person_helmet               0
# driver_license_class        0
# has_motocycle_endorsment    0
# driver_license_state        0
# driver_license_type         0
# person_injury_severity      0
# dtype: int64

# %%
df.to_csv('prepped_svc.csv')

# %% [markdown]
# # Recap

# %% [markdown]
#     We went threw and inputed values from other columns. We addessed none and no data, we inputed nulls where they should respectfully be and converted the resulting dataframe into a new csv named prepped_svc.csv. Now we will get into the explore aspect of this in the next note

# %%
df.person_ethnicity.value_counts()
# Out:
# person_ethnicity
# w - white                          9184
# h - hispanic                       2973
# b - black                          1659
# 99 - unknown                        289
# a - asian                           224
# 98 - other                          125
# i - amer. indian/alaskan native      44
# Name: count, dtype: int64

# %%
df.head()
# Out:
#      crash_id person_age                                             charge
# 0  16189632.0         37                 operate unregistered motor vehicle  \
# 1  16203470.0         30                               no class "m" license
# 2  16191458.0         20  accident involving damage to vehicle>=$200/ fs...
# 3  16192023.0         21                                         no charges
# 4  16196720.0         18                     no driver license no insurance
#
#   person_ethnicity  crash_date day_of_week person_gender
# 0        w - white  2018-01-01      monday      1 - male  \
# 1     h - hispanic  2018-01-04    thursday      1 - male
# 2        w - white  2018-01-05      friday      1 - male
# 3        w - white  2018-01-05      friday      1 - male
# 4     h - hispanic  2018-01-05      friday      1 - male
#
#            person_helmet driver_license_class has_motocycle_endorsment
# 0           1 - not worn          c - class c                        0  \
# 1  3 - worn, not damaged          c - class c                        0
# 2   99 - unknown if worn          c - class c                        0
# 3      2 - worn, damaged          c - class c                        0
# 4           1 - not worn       5 - unlicensed                        0
#
#   driver_license_state driver_license_type        person_injury_severity
# 0           tx - texas  1 - driver license  a - suspected serious injury
# 1           tx - texas  1 - driver license           c - possible injury
# 2           tx - texas  1 - driver license                  99 - unknown
# 3           tx - texas  1 - driver license  a - suspected serious injury
# 4           tx - texas         4 - id card    b - suspected minor injury

# %%
df.person_age.dtype
# Out:
# dtype('O')

# %%
(df.person_injury_severity.value_counts()/ len(df)) * 100
# Out:
# person_injury_severity
# b - suspected minor injury      38.238933
# a - suspected serious injury    27.536431
# c - possible injury             17.610668
# n - not injured                  7.939236
# k - fatal injury                 5.828980
# 99 - unknown                     2.502062
# Name: count, dtype: float64

# %%
df.loc[df['person_injury_severity'] == 'c - possible injury', 'person_injury_severity'] = 'b - suspected minor injury'

# %%
(df.person_injury_severity.value_counts()/ len(df)) * 100
# Out:
# person_injury_severity
# b - suspected minor injury      55.849601
# a - suspected serious injury    27.536431
# n - not injured                  7.939236
# k - fatal injury                 5.828980
# 99 - unknown                     2.502062
# Name: count, dtype: float64

# %%
df.drop(df.loc[df['person_injury_severity'] == '99 - unknown'].index, inplace=True)

# %%
(df.person_injury_severity.value_counts()/ len(df)) * 100
# Out:
# person_injury_severity
# b - suspected minor injury      57.282854
# a - suspected serious injury    28.243091
# n - not injured                  8.142978
# k - fatal injury                 5.978567
# Name: count, dtype: float64

# %% [markdown]
# changing the target variable name to:
# Killed
# Serious
# Minor + Possible
# Not injured
# Unknown REMOVE
