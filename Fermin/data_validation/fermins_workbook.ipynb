# %% [markdown]
# Table: Crashes
# - CrashID (Primary Key, Auto Increment) - System-generated unique identifying number for a crash
# - UnitNumber - Unit number entered on crash report for a unit involved in the crash
# - PersonNumber - Person number captured on the crash report
# - PersonType - Type of person involved in the crash
# - Location - The physical location of an occupant in, on, or outside of the motor vehicle prior to the First Harmful Event or loss of control
# - InjurySeverity - Severity of injury to the occupant
# - Age - Age of person involved in the crash
# - Ethnicity - Ethnicity of person involved in the crash
# - Gender - Gender of person involved in the crash
# - BodyExpulsion - The extent to which the person's body was expelled from the vehicle during any part of the crash
# - RestraintType - The type of restraint used by each occupant
# - AirbagDeployment - Indicates whether a person's airbag deployed during the crash and in what manner
# - HelmetWorn - Indicates if a helmet was worn at the time of the crash
# - Solicitation - Solicitation information
# - AlcoholSpecimenType - Type of alcohol specimen taken for analysis from the primary persons involved in the crash
# - AlcoholResult - Numeric blood alcohol content test result for a primary person involved in the crash, using standardized alcohol breath results (i.e. .08 or .129)
# - DrugSpecimenType - Type of drug specimen taken for analysis from the primary persons involved in the crash
# - DrugTestResult - Primary person drug test result
# - TimeOfDeath - Time of death
#
# Table: InjuryCounts
# - CrashID (Foreign Key) - CrashID referencing the CrashID in the Crashes table
# - SuspectedSeriousInjuryCount - Count of suspected serious injuries
# - NonIncapacitatingInjuryCount - Count of non-incapacitating injuries
# - PossibleInjuryCount - Count of possible injuries
# - NotInjuredCount - Count of individuals not injured
# - UnknownInjuryCount - Count of individuals with unknown injuries
# - TotalInjuryCount - Total count of injuries
# - DeathCount - Count of deaths

# %%
import pandas as pd
import numpy as np
import os
import pandas as pd
from glob import glob
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)

# %%
def get_single_motorcycle_crashes(df):
    '''
    Takes in a pandas dataframe that needs to be filtered down to only single motorcycle crash incidents.
    This will only work if you have an existing 'Crash ID' column.

    INPUT:
    df = Pandas dataframe with data that needs to be filtered down into only crashes with a single motorcycle

    OUTPUT:
    new_df = Filtered dataframe with only single motorcycle crashes
    '''
    original_df = df
    original_df = original_df.reset_index()
    count_of_people_involved_in_crash = original_df['crash_id'].value_counts()
    crashes_with_only_one_person = count_of_people_involved_in_crash[count_of_people_involved_in_crash == 1].index
    crashes_with_only_one_person = crashes_with_only_one_person.to_list()
    new_df = original_df[original_df['crash_id'].isin(crashes_with_only_one_person)]
    return new_df


csv_files = [file for file in glob('*.csv') if '_all_person' in file] 

def process_csv_files(csv_files):
    # Read the first CSV file to initialize the dataframe with columns
    df = pd.read_csv(csv_files[0])

    # Iterate over the remaining CSV files and append them to the dataframe
    for file in csv_files[1:]:
        df = pd.concat([df, pd.read_csv(file)], ignore_index=True)

    # Standardize column names
    df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('-', '_')

    # Process the DataFrame for single motorcycle crashes
    df_svc = get_single_motorcycle_crashes(df)

    # Standardize the text in the DataFrame
    df_svc = df_svc.applymap(lambda x: x.lower().strip() if isinstance(x, str) else x)
    # Replace 'no data' with an empty string
    df_svc.replace('no data', '', inplace=True)

    return df_svc





csv_files = [file for file in glob('*.csv') if '_all_person' in file] 
# # Read the first CSV file to initialize the dataframe with columns
# df = pd.read_csv(csv_files[0])

# # Iterate over the remaining CSV files and append them to the dataframe
# for file in csv_files[1:]:
#     df = pd.concat([df, pd.read_csv(file)], ignore_index=True)
    
# df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('-', '_')

# df_svc = get_single_motorcycle_crashes(df)

# # Standardize the text in the DataFrame
# df_svc = df_svc.applymap(lambda x: x.lower().strip() if isinstance(x, str) else x)
# # Replace 'no data' with an empty string
# df_svc.replace('no data', '', inplace=True)

# %%
process_csv_files(csv_files)
# Out:
#        index  crash_id                     charge      citation person_age person_airbag_deployed person_alcohol_result person_alcohol_specimen_type_taken person_blood_alcohol_content_test_result  person_death_count person_drug_specimen_type person_drug_test_result       person_ejected person_ethnicity person_gender          person_helmet        person_injury_severity  person_non_suspected_serious_injury_count  person_not_injured_count  person_possible_injury_count person_restraint_used  person_suspected_serious_injury_count person_time_of_death  person_total_injury_count                            person_type  person_unknown_injury_count     physical_location_of_an_occupant
# 0          0  19202337                 no charges                       24    97 - not applicable                                                96 - none                                                            0                 96 - none     97 - not applicable  97 - not applicable        w - white      1 - male           1 - not worn           c - possible injury                                          0                         0                             1   97 - not applicable                                      0                                               1  5 - driver of motorcycle type vehicle                            0  1 - front left or motorcycle driver
# 11        11  19185965                 no charges                       75    97 - not applicable                                                96 - none                                                            0                 96 - none     97 - not applicable  97 - not applicable        w - white      1 - male  3 - worn, not damaged               n - not injured                                          0                         1                             0   97 - not applicable                                      0                                               0  5 - driver of motorcycle type vehicle                            0  1 - front left or motorcycle driver
# 12        12  19071274  fail to drive single lane  tx6dlm0doxpg         60    97 - not applicable                                                96 - none                                                            0                 96 - none     97 - not applicable  97 - not applicable        w - white      1 - male  3 - worn, not damaged    b - suspected minor injury                                          1                         0                             0   97 - not applicable                                      0                                               1  5 - driver of motorcycle type vehicle                            0  1 - front left or motorcycle driver
# 13        13  18923820                 no charges                       52    97 - not applicable          1 - positive                          2 - blood                                    0.184                   1                 2 - blood            1 - positive  97 - not applicable        w - white      1 - male           1 - not worn              k - fatal injury                                          0                         0                             0   97 - not applicable                                      0                 1808                          0  5 - driver of motorcycle type vehicle                            0  1 - front left or motorcycle driver
# 27        27  19120390                 no charges                       29    97 - not applicable                                                96 - none                                                            0                 96 - none     97 - not applicable  97 - not applicable        w - white      1 - male   99 - unknown if worn               n - not injured                                          0                         1                             0   97 - not applicable                                      0                                               0  5 - driver of motorcycle type vehicle                            0  1 - front left or motorcycle driver
# ...      ...       ...                        ...           ...        ...                    ...                   ...                                ...                                      ...                 ...                       ...                     ...                  ...              ...           ...                    ...                           ...                                        ...                       ...                           ...                   ...                                    ...                  ...                        ...                                    ...                          ...                                  ...
# 81139  81139  17514238                 no charges                       44    97 - not applicable                                                96 - none                                                            0                 96 - none     97 - not applicable  97 - not applicable        w - white      1 - male      2 - worn, damaged               n - not injured                                          0                         1                             0   97 - not applicable                                      0                                               0  5 - driver of motorcycle type vehicle                            0  1 - front left or motorcycle driver
# 81140  81140  17202931                 no charges                       27    97 - not applicable                                                96 - none                                                            0                 96 - none     97 - not applicable  97 - not applicable        w - white      1 - male      2 - worn, damaged  a - suspected serious injury                                          0                         0                             0   97 - not applicable                                      1                                               1  5 - driver of motorcycle type vehicle                            0  1 - front left or motorcycle driver
# 81143  81143  17202929                 no charges                       26    97 - not applicable                                                96 - none                                                            0                 96 - none     97 - not applicable  97 - not applicable        w - white      1 - male      2 - worn, damaged    b - suspected minor injury                                          1                         0                             0   97 - not applicable                                      0                                               1  5 - driver of motorcycle type vehicle                            0  1 - front left or motorcycle driver
# 81149  81149  17366774                 no charges                       32    97 - not applicable          1 - positive                          2 - blood                                    0.265                   1                 2 - blood            2 - negative  97 - not applicable        w - white      1 - male           1 - not worn              k - fatal injury                                          0                         0                             0   97 - not applicable                                      0                 0023                          0  5 - driver of motorcycle type vehicle                            0  1 - front left or motorcycle driver
# 81150  81150  16973565                 no charges                       54    97 - not applicable                                                96 - none                                                            0                 96 - none     97 - not applicable  97 - not applicable        w - white      1 - male  3 - worn, not damaged           c - possible injury                                          0                         0                             1   97 - not applicable                                      0                                               1  5 - driver of motorcycle type vehicle                            0  1 - front left or motorcycle driver
#
# [14557 rows x 27 columns]

# %%
# Get list of all CSV files in the project directory with "_all_persons" in the file name
csv_files = [file for file in glob('*.csv') if '_all_person' in file]

# %%
csv_files
# Out:
# ['2022_all_person.csv',
#  '2021_all_person.csv',
#  '2020_all_person.csv',
#  '2018_all_person.csv',
#  '2019_all_person.csv']

# %%
# Read the first CSV file to initialize the dataframe with columns
df = pd.read_csv(csv_files[0])

# Iterate over the remaining CSV files and append them to the dataframe
for file in csv_files[1:]:
    df = pd.concat([df, pd.read_csv(file)], ignore_index=True)
    
df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('-', '_')

# Display the combined dataframe
df.head()
# Out:
#    crash_id                                      charge          citation person_age person_airbag_deployed person_alcohol_result person_alcohol_specimen_type_taken person_blood_alcohol_content_test_result  person_death_count person_drug_specimen_type person_drug_test_result       person_ejected person_ethnicity person_gender        person_helmet person_injury_severity  person_non_suspected_serious_injury_count  person_not_injured_count  person_possible_injury_count    person_restraint_used  person_suspected_serious_injury_count person_time_of_death  person_total_injury_count                            person_type  person_unknown_injury_count     physical_location_of_an_occupant
# 0  19202337                                  NO CHARGES           No Data         24    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE         1 - NOT WORN    C - POSSIBLE INJURY                                          0                         0                             1      97 - NOT APPLICABLE                                      0              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 1  19136802                                  NO CHARGES           No Data         64    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE     H - HISPANIC      1 - MALE         1 - NOT WORN    C - POSSIBLE INJURY                                          0                         0                             1      97 - NOT APPLICABLE                                      0              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 2  19136802                                  NO CHARGES           No Data         46       1 - NOT DEPLOYED               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE               1 - NO        W - WHITE      1 - MALE  97 - NOT APPLICABLE        N - NOT INJURED                                          0                         1                             0  1 - SHOULDER & LAP BELT                                      0              No Data                          0                             1 - DRIVER                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 3  19120420                                  NO CHARGES           No Data         25    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE    2 - WORN, DAMAGED    C - POSSIBLE INJURY                                          0                         0                             1      97 - NOT APPLICABLE                                      0              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 4  19120420  NO DRIVER'S LICENSE, FTYROW - TURNING LEFT  L081650, L081650         42       1 - NOT DEPLOYED               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE     H - HISPANIC      1 - MALE  97 - NOT APPLICABLE        N - NOT INJURED                                          0                         1                             0  1 - SHOULDER & LAP BELT                                      0              No Data                          0                             1 - DRIVER                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER

# %%
def get_single_motorcycle_crashes(df):
    '''
    Takes in a pandas dataframe that needs to be filtered down to only single motorcycle crash incidents.
    This will only work if you have an existing 'Crash ID' column.

    INPUT:
    df = Pandas dataframe with data that needs to be filtered down into only crashes with a single motorcycle

    OUTPUT:
    new_df = Filtered dataframe with only single motorcycle crashes
    '''
    original_df = df
    original_df = original_df.reset_index()
    count_of_people_involved_in_crash = original_df['crash_id'].value_counts()
    crashes_with_only_one_person = count_of_people_involved_in_crash[count_of_people_involved_in_crash == 1].index
    crashes_with_only_one_person = crashes_with_only_one_person.to_list()
    new_df = original_df[original_df['crash_id'].isin(crashes_with_only_one_person)]
    return new_df

# %%
df_svc = get_single_motorcycle_crashes(df)

# %%
df_svc
# Out:
#        index  crash_id                     charge      citation person_age person_airbag_deployed person_alcohol_result person_alcohol_specimen_type_taken person_blood_alcohol_content_test_result  person_death_count person_drug_specimen_type person_drug_test_result       person_ejected person_ethnicity person_gender          person_helmet        person_injury_severity  person_non_suspected_serious_injury_count  person_not_injured_count  person_possible_injury_count person_restraint_used  person_suspected_serious_injury_count person_time_of_death  person_total_injury_count                            person_type  person_unknown_injury_count     physical_location_of_an_occupant
# 0          0  19202337                 NO CHARGES       No Data         24    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE           1 - NOT WORN           C - POSSIBLE INJURY                                          0                         0                             1   97 - NOT APPLICABLE                                      0              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 11        11  19185965                 NO CHARGES       No Data         75    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE  3 - WORN, NOT DAMAGED               N - NOT INJURED                                          0                         1                             0   97 - NOT APPLICABLE                                      0              No Data                          0  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 12        12  19071274  FAIL TO DRIVE SINGLE LANE  TX6DLM0DOXPG         60    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE  3 - WORN, NOT DAMAGED    B - SUSPECTED MINOR INJURY                                          1                         0                             0   97 - NOT APPLICABLE                                      0              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 13        13  18923820                 NO CHARGES       No Data         52    97 - NOT APPLICABLE          1 - POSITIVE                          2 - BLOOD                                    0.184                   1                 2 - BLOOD            1 - POSITIVE  97 - NOT APPLICABLE        W - WHITE      1 - MALE           1 - NOT WORN              K - FATAL INJURY                                          0                         0                             0   97 - NOT APPLICABLE                                      0                 1808                          0  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 27        27  19120390                 NO CHARGES       No Data         29    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE   99 - UNKNOWN IF WORN               N - NOT INJURED                                          0                         1                             0   97 - NOT APPLICABLE                                      0              No Data                          0  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# ...      ...       ...                        ...           ...        ...                    ...                   ...                                ...                                      ...                 ...                       ...                     ...                  ...              ...           ...                    ...                           ...                                        ...                       ...                           ...                   ...                                    ...                  ...                        ...                                    ...                          ...                                  ...
# 81139  81139  17514238                 NO CHARGES       No Data         44    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE      2 - WORN, DAMAGED               N - NOT INJURED                                          0                         1                             0   97 - NOT APPLICABLE                                      0              No Data                          0  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 81140  81140  17202931                 NO CHARGES       No Data         27    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE      2 - WORN, DAMAGED  A - SUSPECTED SERIOUS INJURY                                          0                         0                             0   97 - NOT APPLICABLE                                      1              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 81143  81143  17202929                 NO CHARGES       No Data         26    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE      2 - WORN, DAMAGED    B - SUSPECTED MINOR INJURY                                          1                         0                             0   97 - NOT APPLICABLE                                      0              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 81149  81149  17366774                 NO CHARGES       No Data         32    97 - NOT APPLICABLE          1 - POSITIVE                          2 - BLOOD                                    0.265                   1                 2 - BLOOD            2 - NEGATIVE  97 - NOT APPLICABLE        W - WHITE      1 - MALE           1 - NOT WORN              K - FATAL INJURY                                          0                         0                             0   97 - NOT APPLICABLE                                      0                 0023                          0  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 81150  81150  16973565                 NO CHARGES       No Data         54    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE  3 - WORN, NOT DAMAGED           C - POSSIBLE INJURY                                          0                         0                             1   97 - NOT APPLICABLE                                      0              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
#
# [14557 rows x 27 columns]

# %%
# Standardize the text in the DataFrame
df_svc = df_svc.applymap(lambda x: x.lower().strip() if isinstance(x, str) else x)
# Replace 'no data' with an empty string
df_svc.replace('no data', '', inplace=True)

# %%
df_svc.isna().sum()
# Out:
# index                                         0
# crash_id                                      0
# charge                                        9
# citation                                     15
# person_age                                    0
# person_airbag_deployed                        0
# person_alcohol_result                         0
# person_alcohol_specimen_type_taken            0
# person_blood_alcohol_content_test_result      0
# person_death_count                            0
# person_drug_specimen_type                     0
# person_drug_test_result                       0
# person_ejected                                0
# person_ethnicity                              0
# person_gender                                 0
# person_helmet                                 0
# person_injury_severity                        0
# person_non_suspected_serious_injury_count     0
# person_not_injured_count                      0
# person_possible_injury_count                  0
# person_restraint_used                         0
# person_suspected_serious_injury_count         0
# person_time_of_death                          0
# person_total_injury_count                     0
# person_type                                   0
# person_unknown_injury_count                   0
# physical_location_of_an_occupant              0
# dtype: int64

# %% [markdown]
# ## Fucntion work

# %%
# we want to get the get_single_motorcycle_crashes and motorcycle accidents 
df.head()
# Out:
#    crash_id                                      charge          citation person_age person_airbag_deployed person_alcohol_result person_alcohol_specimen_type_taken person_blood_alcohol_content_test_result  person_death_count person_drug_specimen_type person_drug_test_result       person_ejected person_ethnicity person_gender        person_helmet person_injury_severity  person_non_suspected_serious_injury_count  person_not_injured_count  person_possible_injury_count    person_restraint_used  person_suspected_serious_injury_count person_time_of_death  person_total_injury_count                            person_type  person_unknown_injury_count     physical_location_of_an_occupant
# 0  19202337                                  NO CHARGES           No Data         24    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE         1 - NOT WORN    C - POSSIBLE INJURY                                          0                         0                             1      97 - NOT APPLICABLE                                      0              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 1  19136802                                  NO CHARGES           No Data         64    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE     H - HISPANIC      1 - MALE         1 - NOT WORN    C - POSSIBLE INJURY                                          0                         0                             1      97 - NOT APPLICABLE                                      0              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 2  19136802                                  NO CHARGES           No Data         46       1 - NOT DEPLOYED               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE               1 - NO        W - WHITE      1 - MALE  97 - NOT APPLICABLE        N - NOT INJURED                                          0                         1                             0  1 - SHOULDER & LAP BELT                                      0              No Data                          0                             1 - DRIVER                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 3  19120420                                  NO CHARGES           No Data         25    97 - NOT APPLICABLE               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE        W - WHITE      1 - MALE    2 - WORN, DAMAGED    C - POSSIBLE INJURY                                          0                         0                             1      97 - NOT APPLICABLE                                      0              No Data                          1  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 4  19120420  NO DRIVER'S LICENSE, FTYROW - TURNING LEFT  L081650, L081650         42       1 - NOT DEPLOYED               No Data                          96 - NONE                                  No Data                   0                 96 - NONE     97 - NOT APPLICABLE  97 - NOT APPLICABLE     H - HISPANIC      1 - MALE  97 - NOT APPLICABLE        N - NOT INJURED                                          0                         1                             0  1 - SHOULDER & LAP BELT                                      0              No Data                          0                             1 - DRIVER                            0  1 - FRONT LEFT OR MOTORCYCLE DRIVER

# %%
filtered_df = df[~df['crash_id'].duplicated(keep=False)]
filtered_df = filtered_df[filtered_df.person_type == '5 - DRIVER OF MOTORCYCLE TYPE VEHICLE']

# %%
crash_id_master = filtered_df.crash_id

# %%
test = df[~df['crash_id'].duplicated(keep=False)]

# %%
test.person_type.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# 11       5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# 12       5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# 13       5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# 27       5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
#                          ...
# 81139    5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# 81140    5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# 81143    5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# 81149    5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# 81150    5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# Name: person_type, Length: 14557, dtype: object>

# %%
import functions as f

# %%
lat_long_files = f.get_csv_files(keyword='lat_long')

# %%
# test_maseter_lat_long = f.process_csv_files(csv_files= lat_long_files)

# %% [markdown]
# ## Data Validation

# %%
svc_master = pd.read_csv('new_svcs (2).csv')
svc_master.columns = svc_master.columns.str.lower().str.replace(' ', '_').str.replace('-', '_')

# %%
filtered_df_1 = svc_master[~svc_master['crash_id'].duplicated(keep=False)]
filtered_df_1 = filtered_df_1[filtered_df_1.person_type == '5 - DRIVER OF MOTORCYCLE TYPE VEHICLE']

# %%
filtered_df_1.head()
# Out:
#    crash_id $1000_damage_to_any_one_person's_property active_school_zone_flag adjusted_average_daily_traffic_amount adjusted_percentage_of_average_daily_traffic_for_trucks adjusted_roadway_part                                       agency  at_intersection_flag average_daily_traffic_amount average_daily_traffic_year      case_id                 city                         contributing_factors control_section control_section_milepoint      county  crash_date  crash_month  crash_number                crash_severity  crash_time  crash_year day_of_week      dfo highway_alpha_suffix highway_lane_design highway_number highway_system    hour_of_day inside_shoulder_width_on_divided_highway intersecting_highway_alpha_suffix intersecting_highway_number intersecting_highway_system intersecting_street_name  intersection_related     latitude left_curb_type left_shoulder_type left_shoulder_use left_shoulder_width        light_condition     longitude                 manner_of_collision median_type median_width median_width_plus_both_inside_shoulders medical_advisory_flag                                                mpo number_of_entering_roads number_of_lanes         object_struck on_system_flag                                       other_factor outside_shoulder_width_on_divided_highway percentage_of_combo_truck_average_daily_traffic percentage_of_single_unit_truck_average_daily_traffic physical_feature_1 physical_feature_2       population_group private_drive_flag property_damages reference_marker_number reference_marker_offset_distance right_curb_type right_of_way_usual_width right_shoulder_type right_shoulder_use right_shoulder_width road_base_type   road_class roadbed_width    roadway_alignment roadway_function          roadway_part roadway_relation roadway_type rural_flag rural_urban_type  speed_limit      street_name street_number surface_condition surface_width toll_road_flag               traffic_control_type txdot_reportable_flag weather_condition                contributing_factor_1 contributing_factor_2 contributing_factor_3 driver_blood_alcohol_content_test_result driver_drug_test_result driver_license_class driver_license_endorsements driver_license_restrictions driver_license_state driver_license_type emergency_responder_flag financial_responsibility_proof     financial_responsibility_type license_plate_state possible_contributing_factor_1 possible_contributing_factor_2          possible_vehicle_defect_1 vehicle_body_style vehicle_color              vehicle_damage_rating_1___area vehicle_damage_rating_1___direction_of_force vehicle_damage_rating_1___severity            vehicle_damage_rating_2___area vehicle_damage_rating_2___direction_of_force vehicle_damage_rating_2___severity vehicle_defect_1 vehicle_hit_and_run_flag vehicle_inventoried_flag                  vehicle_make                                 vehicle_model_name vehicle_model_year vehicle_parked_flag              vehicle_towed_by              vehicle_towed_to vehicle_travel_direction                                             charge       citation person_age person_ethnicity person_gender          person_helmet        person_injury_severity                            person_type     physical_location_of_an_occupant
# 0  16189632                                        No                      NO                               no data                                            no data       1 - MAIN/PROPER LANE  DEPARTMENT OF PUBLIC SAFETY, STATE OF TEXAS                 False                      no data                    no data      1848553  OUTSIDE CITY LIMITS                 OTHER (EXPLAIN IN NARRATIVE)         no data                   no data   JIM WELLS  2018-01-01            1    2018006416  A - SUSPECTED SERIOUS INJURY        1123        2018      MONDAY  no data                   -1             no data        no data        no data  11:00 - 11:59                                  no data                           no data                     no data                     no data                  no data      NON INTERSECTION  28.04319507        no data            no data           no data             no data      3 - DARK, LIGHTED   -97.9290595  ONE MOTOR VEHICLE - GOING STRAIGHT     no data      no data                                 no data                    No                                            no data      97 - NOT APPLICABLE         no data            OVERTURNED             No                                     NOT APPLICABLE                                   no data                                         no data                                            no data        NOT APPLICABLE     NOT APPLICABLE                  RURAL                 NO             NONE                 no data                          no data         no data                  no data             no data            no data              no data        no data  COUNTY ROAD       no data  1 - STRAIGHT, LEVEL          no data  1 - MAIN/PROPER LANE      OFF ROADWAY      no data        Yes          no data           60  COUNTY ROAD 373           178           1 - DRY       no data             NO  98 - OTHER (EXPLAIN IN NARRATIVE)                   Yes        2 - CLOUDY    98 - OTHER (EXPLAIN IN NARRATIVE)               no data               no data                                  no data     97 - NOT APPLICABLE          C - CLASS C                        NONE                        NONE           TX - TEXAS  1 - DRIVER LICENSE                       No                             NO                           no data          TX - TEXAS                        no data                        no data                            no data    MC - MOTORCYCLE    BLU - BLUE  MC - MOTORCYCLE, SCOOTER, MOPED, ETC. ONLY                                      no data              1 - DAMAGED 1 MINIMUM                                   no data                                      no data                            no data          no data                       No                       NO  OTHER (EXPLAIN IN NARRATIVE)  OTHER (EXPLAIN IN NARRATIVE) (OTHER (EXPLAIN I...            no data                  NO               TAKEN BY FATHER               TAKEN BY FATHER                N - NORTH                 OPERATE UNREGISTERED MOTOR VEHICLE   TX52Q80UKZPL         37        W - WHITE      1 - MALE           1 - NOT WORN  A - SUSPECTED SERIOUS INJURY  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 1  16203470                                        No                      NO                               no data                                            no data       1 - MAIN/PROPER LANE  DEPARTMENT OF PUBLIC SAFETY, STATE OF TEXAS                 False                      no data                    no data      no data  OUTSIDE CITY LIMITS                    ANIMAL ON ROAD - DOMESTIC         no data                   no data     HIDALGO  2018-01-04            1    2018018233           C - POSSIBLE INJURY        1316        2018    THURSDAY  no data                   -1             no data        no data        no data  13:00 - 13:59                                  no data                           no data                     no data                     no data                  no data      NON INTERSECTION  26.29303508        no data            no data           no data             no data           1 - DAYLIGHT  -98.34886112  ONE MOTOR VEHICLE - GOING STRAIGHT     no data      no data                                 no data                    No                                     HIDALGO COUNTY      97 - NOT APPLICABLE         no data        NOT APPLICABLE             No                                     NOT APPLICABLE                                   no data                                         no data                                            no data        NOT APPLICABLE     NOT APPLICABLE                  RURAL                 NO              DOG                 no data                          no data         no data                  no data             no data            no data              no data        no data  COUNTY ROAD       no data  1 - STRAIGHT, LEVEL          no data  1 - MAIN/PROPER LANE       ON ROADWAY      no data        Yes          no data           30    CALIFORNIA ST          6350           1 - DRY       no data             NO                          96 - NONE                   Yes         1 - CLEAR        1 - ANIMAL ON ROAD - DOMESTIC               no data               no data                                  no data     97 - NOT APPLICABLE          C - CLASS C                        NONE      WITH CORRECTIVE LENSES           TX - TEXAS  1 - DRIVER LICENSE                       No                            YES  2 - PROOF OF LIABILITY INSURANCE          TX - TEXAS                        no data                        no data                            no data    MC - MOTORCYCLE    GRY - GRAY  MC - MOTORCYCLE, SCOOTER, MOPED, ETC. ONLY                                      no data              1 - DAMAGED 1 MINIMUM                                   no data                                      no data                            no data          no data                       No                       NO                        SUZUKI                                  GSX-R600 (SUZUKI)               2004                  NO                       no data                       no data                N - NORTH                               NO CLASS "M" LICENSE   TX52QD0NAP34         30     H - HISPANIC      1 - MALE  3 - WORN, NOT DAMAGED           C - POSSIBLE INJURY  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 2  16191458                                       Yes                      NO                               no data                                            no data       1 - MAIN/PROPER LANE           WILLIAMSON COUNTY SHERIFF'S OFFICE                 False                      no data                    no data  20180100170  OUTSIDE CITY LIMITS    UNSAFE SPEED;OTHER (EXPLAIN IN NARRATIVE)         no data                   no data  WILLIAMSON  2018-01-05            1    2018007939                  99 - UNKNOWN        2207        2018      FRIDAY  no data                   -1             no data        no data        no data  22:00 - 22:59                                  no data                           no data                     no data                     no data                  no data      NON INTERSECTION  30.46717132        no data            no data           no data             no data      3 - DARK, LIGHTED   -97.8333446  ONE MOTOR VEHICLE - GOING STRAIGHT     no data      no data                                 no data                    No  CAPITAL AREA METROPOLITAN PLANNING ORGANIZATIO...      97 - NOT APPLICABLE         no data            OVERTURNED             No                                     NOT APPLICABLE                                   no data                                         no data                                            no data        NOT APPLICABLE     NOT APPLICABLE                  RURAL                 NO             NONE                 no data                          no data         no data                  no data             no data            no data              no data        no data  COUNTY ROAD       no data  1 - STRAIGHT, LEVEL          no data  1 - MAIN/PROPER LANE       ON ROADWAY      no data        Yes          no data           35      SABINAL TRL          2794           1 - DRY       no data             NO                          96 - NONE                   Yes         1 - CLEAR    98 - OTHER (EXPLAIN IN NARRATIVE)               no data               no data                                  no data     97 - NOT APPLICABLE          C - CLASS C                        NONE                        NONE           TX - TEXAS  1 - DRIVER LICENSE                       No                            YES  2 - PROOF OF LIABILITY INSURANCE          TX - TEXAS              60 - UNSAFE SPEED                        no data                            no data    MC - MOTORCYCLE   WHI - WHITE    FD - FRONT END DAMAGE DISTRIBUTED IMPACT                              10 - 10 O'CLOCK                      3 - DAMAGED 3  FD - FRONT END DAMAGE DISTRIBUTED IMPACT                                9 - 9 O'CLOCK                      2 - DAMAGED 2          no data                       No                      YES                        YAMAHA                                     YX600 (YAMAHA)               2010                  NO              LAKESIDE WRECKER  12228 ROXIE DR. AUSTIN 78681            UNK - UNKNOWN  ACCIDENT INVOLVING DAMAGE TO VEHICLE>=$200/ FS...  2018-01-00170         20        W - WHITE      1 - MALE   99 - UNKNOWN IF WORN                  99 - UNKNOWN  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 3  16192023                                       Yes                      NO                               no data                                            no data       1 - MAIN/PROPER LANE               HARRIS COUNTY SHERIFF'S OFFICE                 False                      no data                    no data    180002640  OUTSIDE CITY LIMITS  FAILED TO DRIVE IN SINGLE LANE;UNSAFE SPEED         no data                   no data      HARRIS  2018-01-05            1    2018008161  A - SUSPECTED SERIOUS INJURY        2045        2018      FRIDAY  no data                   -1             no data        no data        no data  20:00 - 20:59                                  no data                           no data                     no data                     no data                  no data      NON INTERSECTION  29.95793172        no data            no data           no data             no data  2 - DARK, NOT LIGHTED  -95.64982499  ONE MOTOR VEHICLE - GOING STRAIGHT     no data      no data                                 no data                    No              HOUSTON-GALVESTON AREA COUNCIL (HGAC)      97 - NOT APPLICABLE         no data  HIT CULVERT-HEADWALL             No                                     NOT APPLICABLE                                   no data                                         no data                                            no data        NOT APPLICABLE     NOT APPLICABLE                  RURAL                 NO             NONE                 no data                          no data         no data                  no data             no data            no data              no data        no data  COUNTY ROAD       no data  1 - STRAIGHT, LEVEL          no data  1 - MAIN/PROPER LANE      OFF ROADWAY      no data        Yes          no data           45         TELGE RD       no data           1 - DRY       no data             NO                  17 - MARKED LANES                   Yes         1 - CLEAR  23 - FAILED TO DRIVE IN SINGLE LANE               no data               no data                                  no data     97 - NOT APPLICABLE          C - CLASS C                        NONE                        NONE           TX - TEXAS  1 - DRIVER LICENSE                       No                            YES  2 - PROOF OF LIABILITY INSURANCE          TX - TEXAS              60 - UNSAFE SPEED                        no data  11 - DEFECTIVE STEERING MECHANISM    MC - MOTORCYCLE    BLU - BLUE  MC - MOTORCYCLE, SCOOTER, MOPED, ETC. ONLY                                      no data              1 - DAMAGED 1 MINIMUM                                   no data                                      no data                            no data          no data                       No                      YES                        YAMAHA                                     YZFR6 (YAMAHA)               2017                  NO  CERTIFIED TOWING & TRANSPORT                 17715 CLAY RD                S - SOUTH                                         NO CHARGES        no data         21        W - WHITE      1 - MALE      2 - WORN, DAMAGED  A - SUSPECTED SERIOUS INJURY  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE  1 - FRONT LEFT OR MOTORCYCLE DRIVER
# 4  16196720                                        No                      NO                               no data                                            no data       1 - MAIN/PROPER LANE                    MCALLEN POLICE DEPARTMENT                 False                      no data                    no data    2018-1099              MCALLEN                      FAILED TO CONTROL SPEED         no data                   no data     HIDALGO  2018-01-05            1    2018012213    B - SUSPECTED MINOR INJURY         307        2018      FRIDAY  no data                   -1             no data        no data        no data  03:00 - 03:59                                  no data                           no data                     no data                     no data                N 27TH ST  INTERSECTION RELATED   26.2246359        no data            no data           no data             no data  2 - DARK, NOT LIGHTED  -98.24724129  ONE MOTOR VEHICLE - GOING STRAIGHT     no data      no data                                 no data                    No                                     HIDALGO COUNTY      97 - NOT APPLICABLE         no data            OVERTURNED             No  SLOWING/STOPPING - FOR OFFICER, FLAGMAN, OR TR...                                   no data                                         no data                                            no data        NOT APPLICABLE     NOT APPLICABLE  100,000 - 249,999 POP                 NO             NONE                 no data                          no data         no data                  no data             no data            no data              no data        no data  CITY STREET       no data  1 - STRAIGHT, LEVEL          no data  1 - MAIN/PROPER LANE       ON ROADWAY      no data         No          no data           35     TAMARACK AVE          2686           1 - DRY       no data             NO                      8 - STOP SIGN                   Yes         1 - CLEAR         22 - FAILED TO CONTROL SPEED               no data               no data                                  no data     97 - NOT APPLICABLE       5 - UNLICENSED                  UNLICENSED                  UNLICENSED           TX - TEXAS         4 - ID CARD                       No                             NO                           no data          TX - TEXAS                        no data                        no data                            no data    MC - MOTORCYCLE    BLU - BLUE  MC - MOTORCYCLE, SCOOTER, MOPED, ETC. ONLY                                      no data              1 - DAMAGED 1 MINIMUM                                   no data                                      no data                            no data          no data                       No                  no data                        YAMAHA                                     RZ500 (YAMAHA)               2002                  NO                       no data                       no data                S - SOUTH                     NO DRIVER LICENSE NO INSURANCE         667341         18     H - HISPANIC      1 - MALE           1 - NOT WORN    B - SUSPECTED MINOR INJURY  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE  1 - FRONT LEFT OR MOTORCYCLE DRIVER

# %%
for cols in filtered_df_1.columns:
    print( filtered_df_1[cols].value_counts())
# Out:
# crash_id
# 16189632    1
# 18394514    1
# 18382203    1
# 18383951    1
# 18384531    1
#            ..
# 18891909    1
# 18894741    1
# 18875613    1
# 18876202    1
# 19332955    1
# Name: count, Length: 14548, dtype: int64
# $1000_damage_to_any_one_person's_property
# Yes    12581
# No      1967
# Name: count, dtype: int64
# active_school_zone_flag
# NO     14547
# YES        1
# Name: count, dtype: int64
# adjusted_average_daily_traffic_amount
# no data    6711
# 379          29
# 55           26
# 640          20
# 152153       17
#            ...
# 6522          1
# 7004          1
# 6373          1
# 9724          1
# 10030         1
# Name: count, Length: 4267, dtype: int64
# adjusted_percentage_of_average_daily_traffic_for_trucks
# no data    6711
# 3.7         117
# 4.5         105
# 3.3          94
# 5.3          89
#            ...
# 54.4          1
# 44.9          1
# 56            1
# 36.8          1
# 42.9          1
# Name: count, Length: 438, dtype: int64
# adjusted_roadway_part
# 1 - MAIN/PROPER LANE                 12350
# 2 - SERVICE/FRONTAGE ROAD             1061
# 98 - OTHER (EXPLAIN IN NARRATIVE)      380
# 4 - EXIT/OFF RAMP                      375
# 3 - ENTRANCE/ON RAMP                   263
# 5 - CONNECTOR/FLYOVER                  119
# Name: count, dtype: int64
# agency
# DEPARTMENT OF PUBLIC SAFETY, STATE OF TEXAS    4185
# HOUSTON POLICE DEPARTMENT                       864
# SAN ANTONIO POLICE DEPARTMENT                   733
# AUSTIN POLICE DEPARTMENT                        476
# HARRIS COUNTY SHERIFF'S OFFICE                  412
#                                                ...
# SHOREACRES POLICE DEPARTMENT                      1
# NUECES COUNTY CONSTABLE PRECINCT 3                1
# TERRELL COUNTY SHERIFF'S OFFICE                   1
# MOODY POLICE DEPARTMENT                           1
# KRUGERVILLE POLICE DEPARTMENT                     1
# Name: count, Length: 590, dtype: int64
# at_intersection_flag
# False    12556
# True      1992
# Name: count, dtype: int64
# average_daily_traffic_amount
# no data    6711
# 379          29
# 55           26
# 640          20
# 152153       17
#            ...
# 6522          1
# 7004          1
# 6373          1
# 9724          1
# 10030         1
# Name: count, Length: 4267, dtype: int64
# average_daily_traffic_year
# 2019       7837
# no data    6711
# Name: count, dtype: int64
# case_id
# no data         3320
# NONE              11
# .                  9
# 2B550              3
# 22-01425           2
#                 ...
# 202200769          1
# 221170488          1
# SAPD22088613       1
# 22-0007129         1
# 4285964            1
# Name: count, Length: 11202, dtype: int64
# city
# OUTSIDE CITY LIMITS    5531
# HOUSTON                 947
# SAN ANTONIO             743
# AUSTIN                  474
# DALLAS                  420
#                        ...
# VERNON                    1
# WILLS POINT               1
# HIDALGO                   1
# SIMONTON                  1
# OLD RIVER-WINFREE         1
# Name: count, Length: 612, dtype: int64
# contributing_factors
# FAILED TO CONTROL SPEED                                                                                                                                          2152
# OTHER (EXPLAIN IN NARRATIVE)                                                                                                                                     1981
# UNSAFE SPEED                                                                                                                                                     1972
# NONE                                                                                                                                                              966
# FAULTY EVASIVE ACTION                                                                                                                                             905
#                                                                                                                                                                  ...
# ANIMAL ON ROAD - WILD;FAILED TO DRIVE IN SINGLE LANE;UNSAFE SPEED                                                                                                   1
# DISREGARD STOP SIGN OR LIGHT; FATIGUED OR ASLEEP                                                                                                                    1
# FAILED TO DRIVE IN SINGLE LANE; FLEEING OR EVADING POLICE; SPEEDING - (OVERLIMIT)                                                                                   1
# UNSAFE SPEED;UNDER INFLUENCE - ALCOHOL;WRONG SIDE - NOT PASSING                                                                                                     1
# DISREGARD STOP SIGN OR LIGHT;FAILED TO DRIVE IN SINGLE LANE;IMPAIRED VISIBILITY (EXPLAIN IN NARRATIVE);UNDER INFLUENCE - ALCOHOL;OTHER (EXPLAIN IN NARRATIVE)       1
# Name: count, Length: 593, dtype: int64
# control_section
# no data    6633
# 050003       89
# 019603       57
# 001513       50
# 050801       46
#            ...
# 004208        1
# 001104        1
# 032805        1
# 248701        1
# 024804        1
# Name: count, Length: 2702, dtype: int64
# control_section_milepoint
# no data    6633
# 0            13
# 38.213        5
# 9.98          5
# 1.787         5
#            ...
# 15.323        1
# 0.263         1
# 15.135        1
# 14.548        1
# 2.569         1
# Name: count, Length: 6675, dtype: int64
# county
# HARRIS      1738
# BEXAR        938
# DALLAS       871
# TARRANT      860
# TRAVIS       681
#             ...
# STERLING       1
# KENEDY         1
# BAYLOR         1
# LA SALLE       1
# REAGAN         1
# Name: count, Length: 245, dtype: int64
# crash_date
# 2022-03-25    28
# 2022-04-30    27
# 2019-04-20    27
# 2021-11-06    26
# 2020-10-03    26
#               ..
# 2019-11-08     1
# 2018-12-06     1
# 2018-11-12     1
# 2021-11-30     1
# 2019-02-08     1
# Name: count, Length: 1795, dtype: int64
# crash_month
# 6     1503
# 7     1419
# 8     1404
# 5     1403
# 9     1360
# 10    1358
# 4     1345
# 3     1337
# 11    1049
# 12     871
# 2      750
# 1      749
# Name: count, dtype: int64
# crash_number
# 2018006416    1
# 2021343932    1
# 2021331638    1
# 2021333386    1
# 2021333966    1
#              ..
# 2022206967    1
# 2022209781    1
# 2022190697    1
# 2022191285    1
# 2022642109    1
# Name: count, Length: 14548, dtype: int64
# crash_severity
# B - SUSPECTED MINOR INJURY      5578
# A - SUSPECTED SERIOUS INJURY    4016
# C - POSSIBLE INJURY             2569
# N - NOT INJURED                 1162
# K - FATAL INJURY                 849
# 99 - UNKNOWN                     374
# Name: count, dtype: int64
# crash_time
# 1730    68
# 1800    59
# 1600    56
# 1500    54
# 2100    54
#         ..
# 456      1
# 541      1
# 338      1
# 504      1
# 312      1
# Name: count, Length: 1417, dtype: int64
# crash_year
# 2022    3065
# 2021    3010
# 2020    2940
# 2018    2823
# 2019    2710
# Name: count, dtype: int64
# day_of_week
# SATURDAY     3111
# SUNDAY       2793
# FRIDAY       2152
# THURSDAY     1797
# WEDNESDAY    1627
# MONDAY       1540
# TUESDAY      1528
# Name: count, dtype: int64
# dfo
# no data    6601
# 0            24
# 5.066         5
# 0.006         5
# 171.398       5
#            ...
# 1.471         1
# 239.197       1
# 15.369        1
# 144.667       1
# 12.729        1
# Name: count, Length: 7410, dtype: int64
# highway_alpha_suffix
# -1    14116
# E       183
# W        74
# H        19
# D        16
# P        16
# F        16
# J        14
# R        14
# L        13
# C        12
# A        12
# S        11
# B         9
# G         8
# Y         3
# U         2
# K         2
# T         2
# M         2
# X         1
# V         1
# Z         1
# N         1
# Name: count, dtype: int64
# highway_lane_design
# no data         6681
# TWO-WAY         3856
# FREEWAY         2830
# BOULEVARD        996
# EXPRESSWAY       145
# ONE-WAY PAIR      38
# ONE-WAY            2
# Name: count, dtype: int64
# highway_number
# no data    6421
# 0035        539
# 0010        373
# 0045        291
# 0020        216
#            ...
# 1346          1
# 1229          1
# 2296          1
# 2259          1
# 3364          1
# Name: count, Length: 1134, dtype: int64
# highway_system
# no data               6421
# FARM TO MARKET        2366
# INTERSTATE            1934
# STATE HIGHWAY         1455
# US HIGHWAY            1236
# STATE LOOP             381
# RANCH TO MKT           326
# STATE SPUR             129
# BUSINESS US            107
# BUSINESS SH             52
# PARK ROAD               49
# BUSINESS IH             35
# US ALT                  31
# PRINCIPAL ARTERIAL      16
# BUSINESS FM              3
# FM SPUR                  3
# REC ROAD                 2
# RM SPUR                  1
# US SPUR                  1
# Name: count, dtype: int64
# hour_of_day
# 18:00 - 18:59    998
# 17:00 - 17:59    997
# 16:00 - 16:59    989
# 15:00 - 15:59    934
# 19:00 - 19:59    907
# 14:00 - 14:59    853
# 20:00 - 20:59    808
# 21:00 - 21:59    800
# 13:00 - 13:59    777
# 12:00 - 12:59    749
# 22:00 - 22:59    714
# 11:00 - 11:59    635
# 23:00 - 23:59    617
# 10:00 - 10:59    520
# 00:00 - 00:59    498
# 01:00 - 01:59    461
# 02:00 - 02:59    426
# 09:00 - 09:59    378
# 08:00 - 08:59    323
# 07:00 - 07:59    311
# 06:00 - 06:59    272
# 03:00 - 03:59    217
# 05:00 - 05:59    204
# 04:00 - 04:59    160
# Name: count, dtype: int64
# inside_shoulder_width_on_divided_highway
# no data    6681
# 0          1516
# 8          1226
# 10          612
# 4           600
# 20          590
# 3           485
# 12          445
# 2           414
# 1           373
# 6           273
# 24          218
# 16          169
# 14          157
# 22          151
# 9           150
# 5           110
# 18           89
# 7            65
# 11           45
# 32           26
# 21           21
# 15           19
# 19           18
# 13           16
# 36           16
# 28           16
# 25           11
# 17            8
# 26            7
# 30            4
# 34            4
# 23            4
# 44            3
# 38            2
# 54            1
# 48            1
# 46            1
# 31            1
# Name: count, dtype: int64
# intersecting_highway_alpha_suffix
# no data    13957
# -1           549
# E              6
# B              4
# D              4
# J              4
# H              4
# R              4
# A              3
# F              2
# G              2
# S              2
# L              1
# X              1
# W              1
# V              1
# Q              1
# U              1
# M              1
# Name: count, dtype: int64
# intersecting_highway_number
# no data    13957
# 0010          16
# 0020          15
# 1604          12
# 0035          11
#            ...
# 0022           1
# 0707           1
# 0271           1
# 0356           1
# 1431           1
# Name: count, Length: 311, dtype: int64
# intersecting_highway_system
# no data               13957
# FARM TO MARKET          209
# STATE HIGHWAY           119
# STATE LOOP               67
# INTERSTATE               58
# US HIGHWAY               49
# STATE SPUR               21
# BUSINESS US              19
# RANCH TO MKT             14
# BUSINESS IH              11
# BUSINESS SH               9
# US ALT                    8
# PARK ROAD                 3
# BUSINESS FM               1
# FM SPUR                   1
# REC ROAD                  1
# PRINCIPAL ARTERIAL        1
# Name: count, dtype: int64
# intersecting_street_name
# no data            11207
# NOT REPORTED        1140
# UNKNOWN              307
# IH0010                15
# SL1604                12
#                    ...
# W CANTEY ST            1
# KELLEY ST              1
# INDUSTRIAL BLVD        1
# IH0035E                1
# CR0307                 1
# Name: count, Length: 1591, dtype: int64
# intersection_related
# NON INTERSECTION        11991
# INTERSECTION RELATED     1737
# INTERSECTION              491
# DRIVEWAY ACCESS           329
# Name: count, dtype: int64
# latitude
# no data        577
# 29.56799889      8
# 29.54520026      4
# 31.75660027      4
# 32.77201739      3
#               ...
# 31.35005217      1
# 30.46307499      1
# 33.70174024      1
# 29.36226612      1
# 30.16000594      1
# Name: count, Length: 13816, dtype: int64
# left_curb_type
# no data                                   6721
# NONE                                      6711
# CURB-SURFACE DRAINAGE ONLY                 792
# CURB-SUB-SURFACE ONLY                      322
# OVERLAID (RESURFACED, MAY OR NOT OPEN)       2
# Name: count, dtype: int64
# left_shoulder_type
# no data                                       6681
# BITUMINOUS SURFACE (PAVED)                    5572
# NONE (UNPAVED)                                1521
# STABILIZED-SURFACED WITH FLEX (UNPAVED)        337
# EARTH-WITH OR WITHOUT TURF (UNPAVED)           308
# CONCRETE SURFACE (PAVED)                        90
# COMBINATION-SURFACE / STABILIZED (UNPAVED)      39
# Name: count, dtype: int64
# left_shoulder_use
# no data              6681
# EMERGENCY ONLY       6120
# NO DESIGNATED USE    1665
# PARALLEL PARKING       67
# BICYCLE                 9
# BUS                     3
# DIAGONAL PARKING        2
# PEAK ONLY               1
# Name: count, dtype: int64
# left_shoulder_width
# no data    6681
# 0          1516
# 8          1226
# 10          612
# 4           600
# 20          590
# 3           485
# 12          445
# 2           414
# 1           373
# 6           273
# 24          218
# 16          169
# 14          157
# 22          151
# 9           150
# 5           110
# 18           89
# 7            65
# 11           45
# 32           26
# 21           21
# 15           19
# 19           18
# 13           16
# 36           16
# 28           16
# 25           11
# 17            8
# 26            7
# 30            4
# 34            4
# 23            4
# 44            3
# 38            2
# 54            1
# 48            1
# 46            1
# 31            1
# Name: count, dtype: int64
# light_condition
# 1 - DAYLIGHT                         8726
# 3 - DARK, LIGHTED                    2837
# 2 - DARK, NOT LIGHTED                2495
# 6 - DUSK                              239
# 4 - DARK, UNKNOWN LIGHTING            116
# 5 - DAWN                              105
# 99 - UNKNOWN                           21
# 98 - OTHER (EXPLAIN IN NARRATIVE)       9
# Name: count, dtype: int64
# longitude
# no data          577
# -98.33310699       8
# -98.46799634       4
# -106.49513831      4
# -98.22253745       3
#                 ...
# -96.97961416       1
# -100.87246813      1
# -95.62625301       1
# -97.32501244       1
# -98.55886626       1
# Name: count, Length: 13809, dtype: int64
# manner_of_collision
# ONE MOTOR VEHICLE - GOING STRAIGHT                 13237
# ONE MOTOR VEHICLE - TURNING LEFT                     562
# ONE MOTOR VEHICLE - TURNING RIGHT                    560
# ONE MOTOR VEHICLE - OTHER                             67
# SAME DIRECTION - BOTH GOING STRAIGHT-SIDESWIPE        23
# SAME DIRECTION - BOTH GOING STRAIGHT-REAR END         22
# SAME DIRECTION - ONE STRAIGHT-ONE STOPPED             20
# OPPOSITE DIRECTION - ONE STRAIGHT-ONE LEFT TURN       11
# ANGLE - BOTH GOING STRAIGHT                           10
# ONE MOTOR VEHICLE - BACKING                            7
# OTHER                                                  7
# ANGLE - ONE STRAIGHT-ONE RIGHT TURN                    6
# ANGLE - ONE STRAIGHT-ONE STOPPED                       4
# SAME DIRECTION - ONE STRAIGHT-ONE RIGHT TURN           4
# ANGLE - ONE STRAIGHT-ONE LEFT TURN                     3
# SAME DIRECTION - ONE STRAIGHT-ONE LEFT TURN            2
# ANGLE - ONE RIGHT TURN-ONE STOPPED                     1
# OPPOSITE DIRECTION - ONE STRAIGHT-ONE STOPPED          1
# OPPOSITE DIRECTION - BOTH GOING STRAIGHT               1
# Name: count, dtype: int64
# median_type
# no data                        6681
# NO MEDIAN                      3895
# POSITIVE BARRIER RIGID         2149
# UNPROTECTED                     809
# CURBED                          507
# POSITIVE BARRIER FLEXIBLE       430
# POSITIVE BARRIER SEMI-RIGID      77
# Name: count, dtype: int64
# median_width
# no data    6681
# 0          3895
# 2           369
# 40          307
# 4           307
#            ...
# 460           1
# 170           1
# 82            1
# 180           1
# 17            1
# Name: count, Length: 120, dtype: int64
# median_width_plus_both_inside_shoulders
# no data    6681
# 0          3895
# 2           369
# 40          307
# 4           307
#            ...
# 460           1
# 170           1
# 82            1
# 180           1
# 17            1
# Name: count, Length: 120, dtype: int64
# medical_advisory_flag
# No     14432
# Yes      116
# Name: count, dtype: int64
# mpo
# no data                                                      3701
# NORTH CENTRAL TEXAS COUNCIL OF GOVERNMENTS (NCTCOG)          2951
# HOUSTON-GALVESTON AREA COUNCIL (HGAC)                        2614
# SAN ANTONIO-BEXAR COUNTY                                     1157
# CAPITAL AREA METROPOLITAN PLANNING ORGANIZATION (CAMPO)      1099
# EL PASO                                                       445
# HIDALGO COUNTY                                                304
# KILLEEN TEMPLE METROPOLITAN PLANNING ORGANIZATION (KTMPO)     277
# SOUTH EAST TEXAS REGIONAL PLANNING COMMISSION (SETRPC)        210
# PERMIAN BASIN MPO                                             200
# CORPUS CHRISTI                                                189
# LUBBOCK                                                       176
# AMARILLO                                                      171
# TYLER AREA                                                    139
# BRYAN-COLLEGE STATION                                         128
# SHERMAN-DENISON                                               128
# WACO                                                          127
# ABILENE                                                       120
# LAREDO                                                        106
# LONGVIEW                                                       81
# WICHITA FALLS                                                  67
# SAN ANGELO                                                     55
# TEXARKANA                                                      53
# VICTORIA                                                       50
# Name: count, dtype: int64
# number_of_entering_roads
# 97 - NOT APPLICABLE                  10272
# 2 - THREE ENTERING ROADS - T          1824
# 98 - OTHER (EXPLAIN IN NARRATIVE)     1044
# 4 - FOUR ENTERING ROADS                966
# 3 - THREE ENTERING ROADS - Y           328
# 8 - CLOVERLEAF                          45
# 7 - TRAFFIC CIRCLE                      41
# 5 - FIVE ENTERING ROADS                 21
# 6 - SIX ENTERING ROADS                   7
# Name: count, dtype: int64
# number_of_lanes
# no data    6674
# 2          2963
# 4          2614
# 6          1303
# 8           566
# 10          169
# 5            76
# 7            63
# 3            52
# 9            43
# 12           14
# 11            8
# 14            3
# Name: count, dtype: int64
# object_struck
# OVERTURNED                                                          8024
# HIT CURB                                                            1213
# NOT APPLICABLE                                                      1101
# HIT MEDIAN BARRIER (CONCRETE OR CABLE)                               794
# HIT FENCE                                                            488
# HIT GUARDRAIL                                                        303
# OTHER                                                                301
# HIT TREE, SHRUB, LANDSCAPING                                         300
# HIT HIGHWAY SIGN                                                     294
# DITCH                                                                286
# HIT OTHER FIXED OBJECT                                               272
# HIT CONCRETE TRAFFIC BARRIER (NOT IN MEDIAN)                         182
# HIT MAILBOX                                                          134
# HIT HOLE IN ROAD                                                     129
# HIT CULVERT-HEADWALL                                                  94
# PERSON FELL OR JUMPED FROM VEHICLE                                    87
# HIT RETAINING WALL                                                    75
# HIT UTILITY POLE                                                      71
# HIT HOUSE, BUILDING, OR BUILDING FIXTURE                              70
# HIT WORK ZONE BARRICADE, CONES, SIGNS OR MATERIAL                     68
# HIT LUMINAIRE POLE                                                    58
# EMBANKMENT                                                            46
# HIT SIDE OF BRIDGE (BRIDGE RAIL)                                      44
# HIT ATTENUATION DEVICE                                                31
# HIT PIER OR SUPPORT AT UNDERPASS, TUNNEL OR OVERHEAD SIGN BRIDGE      12
# FIRE HYDRANT                                                          11
# HIT FALLEN TREES OR DEBRIS ON ROAD                                    10
# HIT DELINEATOR OR MARKER POST                                         10
# HIT COMMERCIAL SIGN                                                    9
# HIT TRAFFIC SIGNAL POLE OR POST                                        8
# HIT OVERHEAD SIGNAL LIGHT, WIRES, SIGNS, ETC                           5
# JACK-KNIFED                                                            4
# HIT OBJECT FROM ANOTHER VEHICLE IN ROAD                                4
# HIT END OF BRIDGE (ABUTMENT OR RAIL END)                               3
# HIT PREVIOUSLY WRECKED  VEHICLE                                        3
# HIT RAILROAD CROSSING GATES                                            2
# HIT BUS STOP STRUCTURE (BENCH)                                         1
# HIT TRAIN MOVING FORWARD                                               1
# Name: count, dtype: int64
# on_system_flag
# Yes    8148
# No     6400
# Name: count, dtype: int64
# other_factor
# NOT APPLICABLE                                                                  9313
# ATTENTION DIVERTED FROM DRIVING                                                 1313
# LOST CONTROL OR SKIDDED (ICY OR SLICK ROAD, ETC.)                                761
# CONSTRUCTION - WITHIN POSTED ROAD CONSTRUCTION ZONE (NOT RELATED TO CRASH)       442
# SWERVED OR VEERED-AVOIDING VEHICLE PASSING, CHANGING LANES                       336
# SWERVED OR VEERED-AVOIDING ANIMAL IN ROAD                                        263
# SWERVED OR VEERED-AVOIDING VEHICLE STOPPED OR MOVING SLOWLY IN TRAFFIC LANE      254
# VEHICLE CHANGING LANES                                                           218
# SLOWING/STOPPING-FOR TRAFFIC                                                     215
# SWERVED OR VEERED-REASON NOT SPECIFIED                                           212
# SWERVED OR VEERED-AVOIDING VEHICLE ENTERING ROAD                                 194
# CONSTRUCTION-WITHIN POSTED ROAD CONSTRUCTION ZONE (RELATED TO CRASH)             138
# ONE VEHICLE LEAVING DRIVEWAY                                                     128
# SWERVED OR VEERED-FOR SURFACE OR VISIBILITY                                       89
# VEHICLE PASSING OR ATTEMPTING TO PASS ON LEFT                                     74
# SLOWING/STOPPING-REASON NOT SPECIFIED                                             73
# SWERVED OR VEERED - AVOIDING VEHICLE FROM OPPOSITE DIRECTION IN WRONG LANE        73
# ONE VEHICLE ENTERING DRIVEWAY                                                     69
# SLOWING/STOPPING - FOR OFFICER, FLAGMAN, OR TRAFFIC CONTROL                       62
# SWERVED OR VEERED-AVOIDING OBJECT IN ROAD                                         49
# GUSTY WINDS                                                                       46
# CONSTRUCTION-IN OTHER CONSTRUCTION MAINTENANCE AREA (RELATED TO CRASH)            29
# VEHICLE PASSING OR ATTEMPTING TO PASS ON RIGHT                                    21
# SLOWING/STOPPING-TO MAKE RIGHT TURN                                               20
# ONE VEHICLE PARKED IMPROPER LOCATION                                              17
# SLOWING/STOPPING-FOR VEHICLE ENTERING ROAD                                        17
# VISION OBSTRUCTED BY OTHER VISUAL OBSTRUCTIONS                                    16
# VISION OBSTRUCTED BY HEADLIGHT OR SUN GLARE                                       16
# SWERVED OR VEERED-AVOIDING PEDESTRIAN, PEDALCYCLIST, ETC. IN ROAD                 13
# SLOWING/STOPPING-TO MAKE LEFT TURN                                                11
# SLOWING/STOPPING-FOR ANIMAL IN ROAD                                               10
# ONE VEHICLE FORWARD FROM PARKING                                                  10
# FOOT SLIPPED OFF BRAKE OR CLUTCH                                                   7
# SLOWING/STOPPING-TO AVOID PREVIOUS ACCIDENT                                        6
# SWERVED OR VEERED-AVOIDING PREVIOUS ACCIDENT                                       6
# CONSTRUCTION - IN OTHER CONSTRUCTION MAINTENANCE AREA (NOT RELATED TO CRASH)       4
# CRASH OCCURRED ON A BEACH                                                          4
# SCHOOL BUS RELATED CRASH                                                           4
# SLOWING/STOPPING-FOR SURFACE OR VISIBILITY                                         3
# SLOWING/STOPPING-FOR VEHICLE FROM OPPOSITE DIRECTION IN WRONG LANE                 3
# ONE VEHICLE BACKWARD FROM PARKING                                                  3
# SLOWING/STOPPING-FOR OBJECT IN ROAD                                                2
# VISION OBSTRUCTED BY MOVING VEHICLE                                                1
# OPEN DOOR OR OBJECT PROJECTING FROM VEHICLE                                        1
# SLOWING/STOPPING-FOR PEDESTRIAN, PEDALCYCLIST, ETC. IN ROAD                        1
# PASSENGER INTERFERED WITH DRIVER                                                   1
# Name: count, dtype: int64
# outside_shoulder_width_on_divided_highway
# no data    6681
# 20         2089
# 0          1179
# 10          634
# 8           501
# 3           494
# 4           428
# 2           425
# 1           373
# 24          264
# 16          247
# 6           224
# 22          181
# 9           141
# 18          131
# 14          111
# 5           106
# 12           80
# 21           52
# 7            37
# 19           22
# 11           21
# 13           21
# 32           19
# 40           19
# 17           13
# 15           13
# 34            9
# 38            9
# 30            6
# 23            5
# 48            4
# 31            2
# 28            2
# 25            2
# 26            1
# 35            1
# 33            1
# Name: count, dtype: int64
# percentage_of_combo_truck_average_daily_traffic
# no data    6711
# 0.9         199
# 1.3         196
# 1.5         143
# 0.3         143
#            ...
# 50.6          1
# 35.1          1
# 40.5          1
# 33            1
# 31.7          1
# Name: count, Length: 384, dtype: int64
# percentage_of_single_unit_truck_average_daily_traffic
# no data    6711
# 2.6         234
# 3.7         228
# 3.8         227
# 3.5         216
#            ...
# 21.2          1
# 19.1          1
# 21.6          1
# 27.3          1
# 18.3          1
# Name: count, Length: 185, dtype: int64
# physical_feature_1
# NOT APPLICABLE                                           13613
# ENTRANCE TO OR EXIT FROM PRIVATE PROPERTY OR DRIVEWAY      327
# IN A PARKING LOT                                           296
# ONE OR MORE TRAFFIC LANES CLOSED                           122
# PRIVATE DRIVE OR ROAD                                       74
# CROSSOVER FROM ONE FRONTAGE ROAD TO OTHER                   62
# RR GRADE CROSSING                                           31
# ALLEY                                                       12
# OPENING IN MEDIAN                                            7
# PARKING AREA WITHIN RIGHT OF WAY                             4
# Name: count, dtype: int64
# physical_feature_2
# NOT APPLICABLE                      14546
# ALLEY                                   1
# ONE OR MORE TRAFFIC LANES CLOSED        1
# Name: count, dtype: int64
# population_group
# RURAL                    5531
# 250,000 POP AND OVER     3963
# 100,000 - 249,999 POP    1626
# 50,000 - 99,999 POP       864
# 10,000 - 24,999 POP       809
# 25,000 - 49,999 POP       795
# 5,000 - 9,999 POP         413
# TOWN UNDER 2,499 POP      345
# 2,500 - 4,999 POP         202
# Name: count, dtype: int64
# private_drive_flag
# NO     14223
# YES      325
# Name: count, dtype: int64
# property_damages
# NONE                           12798
# FENCE                             87
# BARBED WIRE FENCE                 47
# DOG                               37
# GUARDRAIL                         35
#                                ...
# BELTWAY DISPLAY SIGN               1
# PLANTER                            1
# CENTER MEDIAN CABLE BARRIER        1
# DAMAGE TO CONCRETE CULVERT         1
# GUARD RAIL AND POST                1
# Name: count, Length: 1095, dtype: int64
# reference_marker_number
# no data    6661
# 0294         53
# 0534         51
# 0570         51
# 0566         44
#            ...
# 0523          1
# 0533          1
# 0890          1
# 0505          1
# 0460A         1
# Name: count, Length: 718, dtype: int64
# reference_marker_offset_distance
# no data    6661
# -0.1         62
# 0.2          56
# 0.1          54
# -0.2         54
#            ...
# 1.641         1
# -0.751        1
# 1.132         1
# 0.535         1
# 1.527         1
# Name: count, Length: 2198, dtype: int64
# right_curb_type
# no data                                       6750
# NONE                                          6708
# CURB-SURFACE DRAINAGE ONLY                     623
# CURB-SUB-SURFACE ONLY                          460
# OVERLAID (RESURFACED, NO LONGER FUNCTIONS)       5
# OVERLAID (RESURFACED, MAY OR NOT OPEN)           2
# Name: count, dtype: int64
# right_of_way_usual_width
# no data    6681
# 100        1235
# 300        1116
# 80         1099
# 120         726
#            ...
# 367           1
# 118           1
# 232           1
# 233           1
# 585           1
# Name: count, Length: 242, dtype: int64
# right_shoulder_type
# no data                                       6681
# BITUMINOUS SURFACE (PAVED)                    5897
# NONE (UNPAVED)                                1179
# STABILIZED-SURFACED WITH FLEX (UNPAVED)        379
# EARTH-WITH OR WITHOUT TURF (UNPAVED)           283
# CONCRETE SURFACE (PAVED)                        87
# COMBINATION-SURFACE / STABILIZED (UNPAVED)      42
# Name: count, dtype: int64
# right_shoulder_use
# no data              6681
# EMERGENCY ONLY       6400
# NO DESIGNATED USE    1338
# PARALLEL PARKING       81
# BICYCLE                42
# DIAGONAL PARKING        3
# BUS                     2
# PEAK ONLY               1
# Name: count, dtype: int64
# right_shoulder_width
# no data    6681
# 20         2089
# 0          1179
# 10          634
# 8           501
# 3           494
# 4           428
# 2           425
# 1           373
# 24          264
# 16          247
# 6           224
# 22          181
# 9           141
# 18          131
# 14          111
# 5           106
# 12           80
# 21           52
# 7            37
# 19           22
# 11           21
# 13           21
# 32           19
# 40           19
# 17           13
# 15           13
# 34            9
# 38            9
# 30            6
# 23            5
# 48            4
# 31            2
# 28            2
# 25            2
# 26            1
# 35            1
# 33            1
# Name: count, dtype: int64
# road_base_type
# no data                                14350
# ROADBED SOIL                             121
# STABILIZED EARTH OR FLEX (GRANULAR)       46
# CONCRETE                                  31
# Name: count, dtype: int64
# road_class
# CITY STREET            4612
# US & STATE HIGHWAYS    3351
# FARM TO MARKET         2649
# INTERSTATE             1840
# COUNTY ROAD            1542
# NON TRAFFICWAY          367
# TOLLWAY                 175
# OTHER ROADS              12
# Name: count, dtype: int64
# roadbed_width
# no data    6681
# 76          621
# 28          564
# 80          560
# 24          403
#            ...
# 204           1
# 143           1
# 147           1
# 125           1
# 161           1
# Name: count, Length: 159, dtype: int64
# roadway_alignment
# 1 - STRAIGHT, LEVEL                  8078
# 4 - CURVE, LEVEL                     3176
# 5 - CURVE, GRADE                     1499
# 2 - STRAIGHT, GRADE                  1090
# 3 - STRAIGHT, HILLCREST               306
# 6 - CURVE, HILLCREST                  275
# 98 - OTHER (EXPLAIN IN NARRATIVE)     115
# 99 - UNKNOWN                            9
# Name: count, dtype: int64
# roadway_function
# no data                         6681
# OTHER PRINCIPAL ARTERIAL        1964
# INTERSTATE                      1860
# MAJOR COLLECTOR                 1803
# MINOR ARTERIAL                  1004
# OTHER FREEWAY AND EXPRESSWAY     967
# MINOR COLLECTOR                  266
# LOCAL                              3
# Name: count, dtype: int64
# roadway_part
# 1 - MAIN/PROPER LANE                 12587
# 2 - SERVICE/FRONTAGE ROAD             1007
# 4 - EXIT/OFF RAMP                      328
# 98 - OTHER (EXPLAIN IN NARRATIVE)      283
# 3 - ENTRANCE/ON RAMP                   243
# 5 - CONNECTOR/FLYOVER                  100
# Name: count, dtype: int64
# roadway_relation
# OFF ROADWAY       6803
# ON ROADWAY        6179
# MEDIAN            1132
# NOT APPLICABLE     362
# SHOULDER            72
# Name: count, dtype: int64
# roadway_type
# no data                       6633
# 4 OR MORE LANES, DIVIDED      3948
# 2 LANE, 2 WAY                 2992
# 4 OR MORE LANES, UNDIVIDED     904
# OTHER ROAD TYPE                 71
# Name: count, dtype: int64
# rural_flag
# No     8470
# Yes    6078
# Name: count, dtype: int64
# rural_urban_type
# no data                       6633
# LARGE URBANIZED (200,000+)    3279
# RURAL (<5000)                 3244
# URBANIZED (50,000-199,999)     831
# SMALL URBAN (5000-49,999)      561
# Name: count, dtype: int64
# speed_limit
#  30    2103
#  45    1951
#  55    1793
#  35    1657
#  40    1445
#  60    1394
#  65    1000
#  70     750
#  50     713
#  75     650
# -1      574
#  25     170
#  20     136
#  15      75
#  5       54
#  10      42
#  80      38
#  85       2
#  54       1
# Name: count, dtype: int64
# street_name
# IH0010            366
# IH0035            277
# IH0045            274
# IH0020            177
# IH0035E           133
#                  ...
# TURFWY PARK ST      1
# INDIAN TRL          1
# EDERVILLE RD        1
# FM0972              1
# WINDSOR LN          1
# Name: count, Length: 5951, dtype: int64
# street_number
# no data    7401
# 100          38
# 300          25
# 101          25
# 600          24
#            ...
# 1579          1
# 11743         1
# 1294          1
# 7320          1
# 20955         1
# Name: count, Length: 4791, dtype: int64
# surface_condition
# 1 - DRY                              13257
# 2 - WET                                841
# 7 - SAND, MUD, DIRT                    186
# 98 - OTHER (EXPLAIN IN NARRATIVE)      156
# 3 - STANDING WATER                      69
# 99 - UNKNOWN                            26
# 6 - ICE                                  9
# 5 - SLUSH                                3
# 4 - SNOW                                 1
# Name: count, dtype: int64
# surface_width
# no data    6681
# 48         1283
# 24         1178
# 72          756
# 22          634
#            ...
# 152           1
# 101           1
# 107           1
# 123           1
# 102           1
# Name: count, Length: 127, dtype: int64
# toll_road_flag
# NO     14313
# YES      235
# Name: count, dtype: int64
# traffic_control_type
# 17 - MARKED LANES                                  6435
# 96 - NONE                                          3494
# 11 - CENTER STRIPE/DIVIDER                         1550
# 12 - NO PASSING ZONE                                900
# 5 - SIGNAL LIGHT                                    699
# 8 - STOP SIGN                                       658
# 10 - WARNING SIGN                                   312
# 98 - OTHER (EXPLAIN IN NARRATIVE)                   241
# 9 - YIELD SIGN                                      106
# 3 - OFFICER                                          60
# 2 - INOPERATIVE (EXPLAIN IN NARRATIVE)               25
# 18 - SIGNAL LIGHT WITH RED LIGHT RUNNING CAMERA      16
# 7 - FLASHING YELLOW LIGHT                            13
# 13 - RR GATE/SIGNAL                                  11
# 6 - FLASHING RED LIGHT                                9
# 16 - BIKE LANE                                        7
# 4 - FLAGMAN                                           7
# 15 - CROSSWALK                                        5
# Name: count, dtype: int64
# txdot_reportable_flag
# Yes    14000
# No       548
# Name: count, dtype: int64
# weather_condition
# 1 - CLEAR                            12121
# 2 - CLOUDY                            1811
# 3 - RAIN                               480
# 6 - FOG                                 56
# 8 - SEVERE CROSSWINDS                   39
# 99 - UNKNOWN                            25
# 98 - OTHER (EXPLAIN IN NARRATIVE)        6
# 4 - SLEET/HAIL                           4
# 7 - BLOWING SAND/SNOW                    4
# 5 - SNOW                                 2
# Name: count, dtype: int64
# contributing_factor_1
# 22 - FAILED TO CONTROL SPEED                                        2589
# 60 - UNSAFE SPEED                                                   2421
# 98 - OTHER (EXPLAIN IN NARRATIVE)                                   2066
# no data                                                             1896
# 23 - FAILED TO DRIVE IN SINGLE LANE                                 1213
# 41 - FAULTY EVASIVE ACTION                                           952
# 20 - DRIVER INATTENTION                                              861
# 2 - ANIMAL ON ROAD - WILD                                            604
# 67 - INTOXICATED - ALCOHOL                                           366
# 1 - ANIMAL ON ROAD - DOMESTIC                                        343
# 43 - FLEEING OR EVADING POLICE                                       232
# 61 - SPEEDING - (OVERLIMIT)                                          136
# 45 - HAD BEEN DRINKING                                               122
# 4 - CHANGED LANE WHEN UNSAFE                                          99
# 47 - ILL (EXPLAIN IN NARRATIVE)                                       64
# 44 - FOLLOWED TOO CLOSELY                                             61
# 66 - TURNED WHEN UNSAFE                                               47
# 48 - IMPAIRED VISIBILITY (EXPLAIN IN NARRATIVE)                       37
# 19 - DISTRACTION IN VEHICLE                                           36
# 64 - TURNED IMPROPERLY - WIDE RIGHT                                   36
# 49 - IMPROPER START FROM A STOPPED, STANDING, OR PARKED POSITION      35
# 16 - DISREGARD STOP SIGN OR LIGHT                                     35
# 40 - FATIGUED OR ASLEEP                                               34
# 25 - FAILED TO HEED WARNING SIGN OR TRAFFIC CONTROL DEVICE            26
# 68 - INTOXICATED - DRUG                                               23
# 26 - FAILED TO PASS TO LEFT SAFELY                                    21
# 70 - WRONG SIDE - NOT PASSING                                         20
# 57 - PASSED IN NO PASSING LANE                                        20
# 63 - TURNED IMPROPERLY - CUT CORNER ON LEFT                           16
# 15 - DISREGARD STOP AND GO SIGNAL                                     13
# 42 - FIRE IN VEHICLE                                                  11
# 58 - PASSED ON SHOULDER                                               11
# 18 - DISREGARD WARNING SIGN AT CONSTRUCTION                           11
# 21 - DROVE WITHOUT HEADLIGHTS                                          9
# 27 - FAILED TO PASS TO RIGHT SAFELY                                    8
# 14 - DISABLED IN TRAFFIC LANE                                          8
# 71 - WRONG WAY - ONE WAY ROAD                                          8
# 65 - TURNED IMPROPERLY - WRONG LANE                                    8
# 17 - DISREGARD TURN MARKS AT INTERSECTION                              5
# 73 - ROAD RAGE                                                         4
# 76 - CELL/MOBILE DEVICE USE - OTHER                                    4
# 29 - FAILED TO STOP AT PROPER PLACE                                    4
# 62 - TAKING MEDICATION (EXPLAIN IN NARRATIVE)                          3
# 3 - BACKED WITHOUT SAFETY                                              3
# 77 - CELL/MOBILE DEVICE USE - UNKNOWN                                  3
# 35 - FAILED TO YIELD RIGHT OF WAY - STOP SIGN                          3
# 37 - FAILED TO YIELD RIGHT OF WAY - TURNING LEFT                       3
# 50 - LOAD NOT SECURED                                                  3
# 24 - FAILED TO GIVE HALF OF ROADWAY                                    2
# 39 - FAILED TO YIELD RIGHT OF WAY - YIELD SIGN                         2
# 34 - FAILED TO YIELD RIGHT OF WAY - PRIVATE DRIVE                      2
# 53 - OVERTAKE AND PASS INSUFFICIENT CLEARANCE                          2
# 52 - OVERSIZED VEHICLE OR LOAD                                         1
# 59 - PEDESTRIAN FAILED TO YIELD RIGHT OF WAY TO VEHICLE                1
# 74 - CELL/MOBILE DEVICE USE - TALKING                                  1
# 69 - WRONG SIDE - APPROACH OR INTERSECTION                             1
# 46 - HANDICAPPED DRIVER (EXPLAIN IN NARRATIVE)                         1
# 54 - PARKED AND FAILED TO SET BRAKES                                   1
# 31 - FAILED TO STOP FOR TRAIN                                          1
# Name: count, dtype: int64
# contributing_factor_2
# no data                                                             12487
# 23 - FAILED TO DRIVE IN SINGLE LANE                                   300
# 41 - FAULTY EVASIVE ACTION                                            283
# 60 - UNSAFE SPEED                                                     281
# 20 - DRIVER INATTENTION                                               226
# 22 - FAILED TO CONTROL SPEED                                          207
# 98 - OTHER (EXPLAIN IN NARRATIVE)                                     173
# 67 - INTOXICATED - ALCOHOL                                            159
# 45 - HAD BEEN DRINKING                                                 77
# 61 - SPEEDING - (OVERLIMIT)                                            48
# 25 - FAILED TO HEED WARNING SIGN OR TRAFFIC CONTROL DEVICE             39
# 43 - FLEEING OR EVADING POLICE                                         37
# 68 - INTOXICATED - DRUG                                                31
# 16 - DISREGARD STOP SIGN OR LIGHT                                      24
# 4 - CHANGED LANE WHEN UNSAFE                                           20
# 44 - FOLLOWED TOO CLOSELY                                              15
# 64 - TURNED IMPROPERLY - WIDE RIGHT                                    15
# 70 - WRONG SIDE - NOT PASSING                                          11
# 19 - DISTRACTION IN VEHICLE                                            10
# 48 - IMPAIRED VISIBILITY (EXPLAIN IN NARRATIVE)                         9
# 2 - ANIMAL ON ROAD - WILD                                               9
# 40 - FATIGUED OR ASLEEP                                                 8
# 57 - PASSED IN NO PASSING LANE                                          8
# 1 - ANIMAL ON ROAD - DOMESTIC                                           7
# 63 - TURNED IMPROPERLY - CUT CORNER ON LEFT                             6
# 66 - TURNED WHEN UNSAFE                                                 6
# 21 - DROVE WITHOUT HEADLIGHTS                                           5
# 71 - WRONG WAY - ONE WAY ROAD                                           4
# 24 - FAILED TO GIVE HALF OF ROADWAY                                     4
# 29 - FAILED TO STOP AT PROPER PLACE                                     3
# 47 - ILL (EXPLAIN IN NARRATIVE)                                         3
# 15 - DISREGARD STOP AND GO SIGNAL                                       3
# 27 - FAILED TO PASS TO RIGHT SAFELY                                     3
# 26 - FAILED TO PASS TO LEFT SAFELY                                      3
# 62 - TAKING MEDICATION (EXPLAIN IN NARRATIVE)                           3
# 76 - CELL/MOBILE DEVICE USE - OTHER                                     3
# 53 - OVERTAKE AND PASS INSUFFICIENT CLEARANCE                           2
# 75 - CELL/MOBILE DEVICE USE - TEXTING                                   2
# 77 - CELL/MOBILE DEVICE USE - UNKNOWN                                   2
# 46 - HANDICAPPED DRIVER (EXPLAIN IN NARRATIVE)                          2
# 65 - TURNED IMPROPERLY - WRONG LANE                                     1
# 35 - FAILED TO YIELD RIGHT OF WAY - STOP SIGN                           1
# 59 - PEDESTRIAN FAILED TO YIELD RIGHT OF WAY TO VEHICLE                 1
# 14 - DISABLED IN TRAFFIC LANE                                           1
# 69 - WRONG SIDE - APPROACH OR INTERSECTION                              1
# 49 - IMPROPER START FROM A STOPPED, STANDING, OR PARKED POSITION        1
# 18 - DISREGARD WARNING SIGN AT CONSTRUCTION                             1
# 33 - FAILED TO YIELD RIGHT OF WAY - OPEN INTERSECTION                   1
# 73 - ROAD RAGE                                                          1
# 42 - FIRE IN VEHICLE                                                    1
# Name: count, dtype: int64
# contributing_factor_3
# no data                                                       14295
# 41 - FAULTY EVASIVE ACTION                                       41
# 23 - FAILED TO DRIVE IN SINGLE LANE                              40
# 68 - INTOXICATED - DRUG                                          23
# 20 - DRIVER INATTENTION                                          23
# 98 - OTHER (EXPLAIN IN NARRATIVE)                                20
# 67 - INTOXICATED - ALCOHOL                                       18
# 60 - UNSAFE SPEED                                                17
# 45 - HAD BEEN DRINKING                                           15
# 22 - FAILED TO CONTROL SPEED                                     11
# 61 - SPEEDING - (OVERLIMIT)                                       6
# 4 - CHANGED LANE WHEN UNSAFE                                      5
# 16 - DISREGARD STOP SIGN OR LIGHT                                 5
# 70 - WRONG SIDE - NOT PASSING                                     4
# 64 - TURNED IMPROPERLY - WIDE RIGHT                               4
# 21 - DROVE WITHOUT HEADLIGHTS                                     4
# 25 - FAILED TO HEED WARNING SIGN OR TRAFFIC CONTROL DEVICE        3
# 43 - FLEEING OR EVADING POLICE                                    2
# 18 - DISREGARD WARNING SIGN AT CONSTRUCTION                       2
# 19 - DISTRACTION IN VEHICLE                                       2
# 66 - TURNED WHEN UNSAFE                                           1
# 1 - ANIMAL ON ROAD - DOMESTIC                                     1
# 2 - ANIMAL ON ROAD - WILD                                         1
# 58 - PASSED ON SHOULDER                                           1
# 40 - FATIGUED OR ASLEEP                                           1
# 62 - TAKING MEDICATION (EXPLAIN IN NARRATIVE)                     1
# 27 - FAILED TO PASS TO RIGHT SAFELY                               1
# 17 - DISREGARD TURN MARKS AT INTERSECTION                         1
# Name: count, dtype: int64
# driver_blood_alcohol_content_test_result
# no data    13768
# 0            165
# 0.17          12
# 0.16          12
# 0.15          11
#            ...
# 0.297          1
# 0.267          1
# 0.061          1
# 0.012          1
# 0.242          1
# Name: count, Length: 240, dtype: int64
# driver_drug_test_result
# 97 - NOT APPLICABLE    13963
# 2 - NEGATIVE             208
# 99 - UNKNOWN             193
# 1 - POSITIVE             184
# Name: count, dtype: int64
# driver_license_class
# CM - CLASS C AND M         5458
# C - CLASS C                5271
# 5 - UNLICENSED             1232
# 98 - OTHER/OUT OF STATE     894
# AM - CLASS A AND M          564
# A - CLASS A                 390
# 99 - UNKNOWN                370
# BM - CLASS B AND M          140
# no data                      87
# M - CLASS M                  83
# B - CLASS B                  59
# Name: count, dtype: int64
# driver_license_endorsements
# NONE                                                                                           12018
# UNLICENSED                                                                                      1245
# UNKNOWN                                                                                          447
# OTHER/OUT OF STATE                                                                               231
# TANK VEHICLE                                                                                     198
# TANK VEHICLE, DOUBLE/TRIPLE TRAILER                                                               87
# TANK VEHICLE, HAZARDOUS MATERIALS                                                                 54
# TANK VEHICLE, HAZARDOUS MATERIALS, DOUBLE/TRIPLE TRAILER                                          46
# no data                                                                                           36
# PASSENGER, TANK VEHICLE, DOUBLE/TRIPLE TRAILER                                                    35
# PASSENGER                                                                                         27
# PASSENGER, SCHOOL BUS                                                                             25
# DOUBLE/TRIPLE TRAILER                                                                             20
# TANK VEHICLE WITH HAZARDOUS MATERIALS                                                             11
# ...
# 42 - FIRE IN VEHICLE                                                    2
# 15 - DISREGARD STOP AND GO SIGNAL                                       1
# 17 - DISREGARD TURN MARKS AT INTERSECTION                               1
# 57 - PASSED IN NO PASSING LANE                                          1
# 74 - CELL/MOBILE DEVICE USE - TALKING                                   1
# 29 - FAILED TO STOP AT PROPER PLACE                                     1
# 21 - DROVE WITHOUT HEADLIGHTS                                           1
# 32 - FAILED TO YIELD RIGHT OF WAY - EMERGENCY VEHICLE                   1
# 46 - HANDICAPPED DRIVER (EXPLAIN IN NARRATIVE)                          1
# 75 - CELL/MOBILE DEVICE USE - TEXTING                                   1
# Name: count, dtype: int64
# possible_contributing_factor_2
# no data                                                       14320
# 22 - FAILED TO CONTROL SPEED                                     38
# 20 - DRIVER INATTENTION                                          36
# 98 - OTHER (EXPLAIN IN NARRATIVE)                                30
# 41 - FAULTY EVASIVE ACTION                                       27
# 45 - HAD BEEN DRINKING                                           20
# 68 - INTOXICATED - DRUG                                          12
# 60 - UNSAFE SPEED                                                11
# 23 - FAILED TO DRIVE IN SINGLE LANE                              11
# 67 - INTOXICATED - ALCOHOL                                        6
# 61 - SPEEDING - (OVERLIMIT)                                       5
# 47 - ILL (EXPLAIN IN NARRATIVE)                                   5
# 25 - FAILED TO HEED WARNING SIGN OR TRAFFIC CONTROL DEVICE        4
# 2 - ANIMAL ON ROAD - WILD                                         4
# 44 - FOLLOWED TOO CLOSELY                                         3
# 4 - CHANGED LANE WHEN UNSAFE                                      3
# 19 - DISTRACTION IN VEHICLE                                       3
# 1 - ANIMAL ON ROAD - DOMESTIC                                     2
# 43 - FLEEING OR EVADING POLICE                                    1
# 40 - FATIGUED OR ASLEEP                                           1
# 29 - FAILED TO STOP AT PROPER PLACE                               1
# 66 - TURNED WHEN UNSAFE                                           1
# 26 - FAILED TO PASS TO LEFT SAFELY                                1
# 64 - TURNED IMPROPERLY - WIDE RIGHT                               1
# 77 - CELL/MOBILE DEVICE USE - UNKNOWN                             1
# 62 - TAKING MEDICATION (EXPLAIN IN NARRATIVE)                     1
# Name: count, dtype: int64
# possible_vehicle_defect_1
# no data                                14348
# 12 - DEFECTIVE OR SLICK TIRES             61
# 98 - OTHER  (EXPLAIN IN NARRATIVE)        54
# 10 - DEFECTIVE OR NO VEHICLE BRAKES       47
# 11 - DEFECTIVE STEERING MECHANISM         35
# 5 - DEFECTIVE OR NO HEADLAMPS              2
# 6 - DEFECTIVE OR NO STOP LAMPS             1
# Name: count, dtype: int64
# vehicle_body_style
# MC - MOTORCYCLE           14517
# PM - POLICE MOTORCYCLE       31
# Name: count, dtype: int64
# vehicle_color
# BLK - BLACK                          6310
# RED - RED                            1785
# BLU - BLUE                           1718
# WHI - WHITE                          1115
# SIL - SILVER                          654
# GRY - GRAY                            604
# GRN - GREEN                           503
# MAR - MAROON                          441
# ONG - ORANGE                          366
# MUL - MULTICOLORED                    244
# YEL - YELLOW                          231
# PLE - PURPLE                          129
# no data                                83
# 99 - UNKNOWN                           81
# GLD - GOLD                             79
# BRO - BROWN                            77
# TAN - TAN                              33
# BGE - BEIGE                            27
# TRQ - TURQUOISE(BLUE)                  14
# TEA - TEAL(GREEN)                      13
# PNK - PINK                             11
# 98 - OTHER (EXPLAIN IN NARRATIVE)      10
# BRZ - BRONZE                           10
# CAM - CAMOUFLAGE                        5
# CPR - COPPER                            5
# Name: count, dtype: int64
# vehicle_damage_rating_1___area
# MC - MOTORCYCLE, SCOOTER, MOPED, ETC. ONLY            8765
# FD - FRONT END DAMAGE DISTRIBUTED IMPACT               924
# LD - DISTRIBUTED LEFT SIDE DAMAGE PARALLEL IMPACT      865
# RD - DISTRIBUTED RIGHT SIDE DAMAGE PARALLEL IMPACT     665
# FC - FRONT END DAMAGE CONCENTRATED IMPACT              619
# LP - LEFT SIDE DAMAGE ANGULAR IMPACT                   604
# RP - RIGHT SIDE DAMAGE ANGULAR IMPACT                  533
# no data                                                307
# FL - FRONT END (LEFT) DAMAGE PARTIAL CONTACT           215
# FR - FRONT END (RIGHT)  DAMAGE PARTIAL CONTACT         213
# L&T - LEFT SIDE AND TOP DAMAGE ROLLOVER EFFECTS        182
# R&T - RIGHT SIDE AND TOP DAMAGE ROLLOVER EFFECTS       172
# LFQ - LEFT FRONT QUARTER DAMAGE ANGULAR IMPACT         132
# RFQ - RIGHT FRONT QUARTER DAMAGE ANGULAR IMPACT        125
# VB - VEHICLE BURNED                                     53
# LBQ - LEFT BACK QUARTER DAMAGE ANGULAR IMPACT           36
# RBQ - RIGHT BACK QUARTER DAMAGE ANGULAR IMPACT          35
# BD - BACK END DAMAGE DISTRIBUTED IMPACT                 26
# BC - BACK END DAMAGE CONCENTRATED IMPACT                22
# BL - BACK END (LEFT) DAMAGE PARTIAL CONTACT             18
# VX - UNDERCARRIAGE DAMAGE                               17
# BR - BACK END (RIGHT) DAMAGE PARTIAL CONTACT            14
# TP - TOP DAMAGE                                          3
# NA - NOT APPLICABLE ( FARM TRACTOR, ETC.)                3
# Name: count, dtype: int64
# vehicle_damage_rating_1___direction_of_force
# no data            9616
# 12 - 12 O'CLOCK    1588
# 9 - 9 O'CLOCK      1080
# 3 - 3 O'CLOCK       950
# 1 - 1 O'CLOCK       401
# 11 - 11 O'CLOCK     335
# 2 - 2 O'CLOCK       190
# 10 - 10 O'CLOCK     154
# 6 - 6 O'CLOCK        58
# 7 - 7 O'CLOCK        53
# 4 - 4 O'CLOCK        44
# 5 - 5 O'CLOCK        42
# 8 - 8 O'CLOCK        37
# Name: count, dtype: int64
# vehicle_damage_rating_1___severity
# 1 - DAMAGED 1 MINIMUM    10384
# 2 - DAMAGED 2             1628
# 3 - DAMAGED 3             1145
# 4 - DAMAGED 4              487
# no data                    306
# 5 - DAMAGED 5              262
# 7 - DAMAGED 7 HIGHEST      153
# 0 - NO DAMAGE               95
# 6 - DAMAGED 6               88
# Name: count, dtype: int64
# vehicle_damage_rating_2___area
# no data                                               13597
# RD - DISTRIBUTED RIGHT SIDE DAMAGE PARALLEL IMPACT      140
# LD - DISTRIBUTED LEFT SIDE DAMAGE PARALLEL IMPACT       128
# RP - RIGHT SIDE DAMAGE ANGULAR IMPACT                   123
# LP - LEFT SIDE DAMAGE ANGULAR IMPACT                     90
# FD - FRONT END DAMAGE DISTRIBUTED IMPACT                 66
# BD - BACK END DAMAGE DISTRIBUTED IMPACT                  51
# R&T - RIGHT SIDE AND TOP DAMAGE ROLLOVER EFFECTS         48
# MC - MOTORCYCLE, SCOOTER, MOPED, ETC. ONLY               40
# FC - FRONT END DAMAGE CONCENTRATED IMPACT                35
# L&T - LEFT SIDE AND TOP DAMAGE ROLLOVER EFFECTS          33
# FL - FRONT END (LEFT) DAMAGE PARTIAL CONTACT             28
# RBQ - RIGHT BACK QUARTER DAMAGE ANGULAR IMPACT           27
# LFQ - LEFT FRONT QUARTER DAMAGE ANGULAR IMPACT           26
# FR - FRONT END (RIGHT)  DAMAGE PARTIAL CONTACT           23
# LBQ - LEFT BACK QUARTER DAMAGE ANGULAR IMPACT            20
# RFQ - RIGHT FRONT QUARTER DAMAGE ANGULAR IMPACT          20
# VX - UNDERCARRIAGE DAMAGE                                18
# BC - BACK END DAMAGE CONCENTRATED IMPACT                 14
# BL - BACK END (LEFT) DAMAGE PARTIAL CONTACT              12
# BR - BACK END (RIGHT) DAMAGE PARTIAL CONTACT              5
# TP - TOP DAMAGE                                           2
# NA - NOT APPLICABLE ( FARM TRACTOR, ETC.)                 1
# VB - VEHICLE BURNED                                       1
# Name: count, dtype: int64
# vehicle_damage_rating_2___direction_of_force
# no data            13722
# 3 - 3 O'CLOCK        227
# 9 - 9 O'CLOCK        191
# 12 - 12 O'CLOCK      108
# 6 - 6 O'CLOCK         68
# 11 - 11 O'CLOCK       49
# 1 - 1 O'CLOCK         47
# 2 - 2 O'CLOCK         37
# 10 - 10 O'CLOCK       25
# 4 - 4 O'CLOCK         22
# 5 - 5 O'CLOCK         20
# 7 - 7 O'CLOCK         18
# 8 - 8 O'CLOCK         14
# Name: count, dtype: int64
# vehicle_damage_rating_2___severity
# no data                  13559
# 1 - DAMAGED 1 MINIMUM      314
# 2 - DAMAGED 2              287
# 3 - DAMAGED 3              196
# 4 - DAMAGED 4               79
# 5 - DAMAGED 5               46
# 0 - NO DAMAGE               27
# 7 - DAMAGED 7 HIGHEST       23
# 6 - DAMAGED 6               17
# Name: count, dtype: int64
# vehicle_defect_1
# no data                                14048
# 98 - OTHER  (EXPLAIN IN NARRATIVE)       190
# 12 - DEFECTIVE OR SLICK TIRES            152
# 10 - DEFECTIVE OR NO VEHICLE BRAKES      108
# 11 - DEFECTIVE STEERING MECHANISM         38
# 5 - DEFECTIVE OR NO HEADLAMPS             10
# 13 - DEFECTIVE TRAILER HITCH               1
# 9 - DEFECTIVE OR NO TRAILER BRAKES         1
# Name: count, dtype: int64
# vehicle_hit_and_run_flag
# No     14259
# Yes      289
# Name: count, dtype: int64
# vehicle_inventoried_flag
# NO         10250
# YES         4028
# no data      270
# Name: count, dtype: int64
# vehicle_make
# HARLEY-DAVIDSON    5499
# HONDA              2460
# YAMAHA             1676
# KAWASAKI           1625
# SUZUKI             1463
#                    ...
# BOBKO                 1
# DERBI                 1
# AMERICAN REBEL        1
# DIAMOND REO           1
# IMPERIAL TR SER       1
# Name: count, Length: 69, dtype: int64
# vehicle_model_name
# UNKNOWN (HARLEY-DAVIDSON)    1471
# UNKNOWN (HONDA)               651
# UNKNOWN (YAMAHA)              498
# NINJA ZX (KAWASAKI)           325
# UNKNOWN (SUZUKI)              323
#                              ...
# BASHAN SCOOTER (BASHAN)         1
# SP500 (SUZUKI)                  1
# LT50 (SUZUKI)                   1
# FXDXI (HARLEY-DAVIDSON)         1
# KM100 (KAWASAKI)                1
# Name: count, Length: 981, dtype: int64
# vehicle_model_year
# 2007    1016
# 2006     874
# 2009     784
# 2008     765
# 2017     737
#         ...
# 1965       1
# 1901       1
# 1962       1
# 1971       1
# 1958       1
# Name: count, Length: 63, dtype: int64
# vehicle_parked_flag
# NO    14548
# Name: count, dtype: int64
# vehicle_towed_by
# no data                    3625
# NOT TOWED                   280
# DRIVER                      257
# OWNER                       218
# TEXAS TOWING                176
#                            ...
# PUSHED HOME                   1
# TILLERY WRECKER SERVICE       1
# N.A                           1
# CJ WRECKER                    1
# DAVES HIGHWAY                 1
# Name: count, Length: 4502, dtype: int64
# vehicle_towed_to
# no data                                     4026
# NOT TOWED                                    221
# DRIVEN AWAY                                  173
# GROWDON                                      162
# 11615 RAILROAD                               117
#                                             ...
# 825 MONTAGUE ST NOCONA TX 76255                1
# IREDELL, TEXAS                                 1
# MISSION WRECKER                                1
# 5110 I 30 FRONTAGE, GREENVILLE, TX 75402       1
# 1509 E MAIN ST. GRAND PRAIRIE, TX, 75050       1
# Name: count, Length: 5906, dtype: int64
# vehicle_travel_direction
# N - NORTH         2605
# S - SOUTH         2344
# E - EAST          2296
# W - WEST          2227
# NW - NORTHWEST    1285
# NE - NORTHEAST    1252
# SW - SOUTHWEST    1168
# SE - SOUTHEAST    1100
# UNK - UNKNOWN      271
# Name: count, dtype: int64
# charge
# NO CHARGES                                                                                                                                                                                                                                                10515
# UNSAFE SPEED                                                                                                                                                                                                                                                605
# DRIVING WHILE INTOXICATED                                                                                                                                                                                                                                   159
# FAIL TO CONTROL SPEED                                                                                                                                                                                                                                       110
# FAIL TO DRIVE IN SINGLE LANE                                                                                                                                                                                                                                 79
#                                                                                                                                                                                                                                                           ...
# IMPROPER DL FOR THE TYPE OF VEH (MOTORCYCLE)                                                                                                                                                                                                                  1
# FAIL TO CONTROL SPEED, ATTACHMENT OF INSPECTION CERT-MOTORCYCLE                                                                                                                                                                                               1
# DRIVING WHILE LICENSE INVALID - ENHANCED                                                                                                                                                                                                                      1
# POSSESSION OF SUBSTANCE IN PENALTY GROUP 1 1-4 GRAMS, DRIVING WHILE LICENSE INVALID, FAILED TO MAINTAIN FINANCIAL RESPONSIBILITY, OPERATE MOTOR VEHICLE WITH WRONG LICENSE PLATE, OPERATE UNREGISTERED MOTOR VEHICLE, POSSESSION OF DRUG PARAPHERNALIA        1
# FAIL TO DRIVE IN SINGLE LANE, FAIL TO MAINTAIN FINANCIAL RESPONSIBILITY, SPEEDING, NO MOTORCYCLE LICENSE                                                                                                                                                      1
# Name: count, Length: 2055, dtype: int64
# citation
# no data               10754
# NONE                     17
# SUMMONS                  11
# SUMMONS, SUMMONS          7
# WARNING                   4
#                       ...
# 19536155, 19536155        1
# TX6AJ20DEG2H              1
# WW20170162                1
# 05576                     1
# TX6HCF0DDEIM              1
# Name: count, Length: 3751, dtype: int64
# person_age
# 27    451
# 24    435
# 28    433
# 25    415
# 23    409
#      ...
# 3       1
# 6       1
# 7       1
# 8       1
# 87      1
# Name: count, Length: 86, dtype: int64
# person_ethnicity
# W - WHITE                          9184
# H - HISPANIC                       2973
# B - BLACK                          1659
# 99 - UNKNOWN                        289
# A - ASIAN                           224
# 98 - OTHER                          125
# no data                              50
# I - AMER. INDIAN/ALASKAN NATIVE      44
# Name: count, dtype: int64
# person_gender
# 1 - MALE        13316
# 2 - FEMALE        994
# 99 - UNKNOWN      238
# Name: count, dtype: int64
# person_helmet
# 1 - NOT WORN             5648
# 2 - WORN, DAMAGED        4326
# 3 - WORN, NOT DAMAGED    2445
# 4 - WORN, UNK DAMAGE     1276
# 99 - UNKNOWN IF WORN      853
# Name: count, dtype: int64
# person_injury_severity
# B - SUSPECTED MINOR INJURY      5578
# A - SUSPECTED SERIOUS INJURY    4016
# C - POSSIBLE INJURY             2569
# N - NOT INJURED                 1162
# K - FATAL INJURY                 849
# 99 - UNKNOWN                     374
# Name: count, dtype: int64
# person_type
# 5 - DRIVER OF MOTORCYCLE TYPE VEHICLE    14548
# Name: count, dtype: int64
# physical_location_of_an_occupant
# 1 - FRONT LEFT OR MOTORCYCLE DRIVER    14548
# Name: count, dtype: int64

# %%
len(filtered_df_1)
# Out:
# 14548

# %%
lat_list = f.get_csv_files(keyword='lat')

# %%
df_svc.columns
# Out:
# Index(['index', 'crash_id', 'charge', 'citation', 'person_age',
#        'person_airbag_deployed', 'person_alcohol_result',
#        'person_alcohol_specimen_type_taken',
#        'person_blood_alcohol_content_test_result', 'person_death_count',
#        'person_drug_specimen_type', 'person_drug_test_result',
#        'person_ejected', 'person_ethnicity', 'person_gender', 'person_helmet',
#        'person_injury_severity', 'person_non_suspected_serious_injury_count',
#        'person_not_injured_count', 'person_possible_injury_count',
#        'person_restraint_used', 'person_suspected_serious_injury_count',
#        'person_time_of_death', 'person_total_injury_count', 'person_type',
#        'person_unknown_injury_count', 'physical_location_of_an_occupant'],
#       dtype='object')

# %%
df_svc.person_injury_severity
# Out:
# 0                 c - possible injury
# 11                    n - not injured
# 12         b - suspected minor injury
# 13                   k - fatal injury
# 27                    n - not injured
#                      ...
# 81139                 n - not injured
# 81140    a - suspected serious injury
# 81143      b - suspected minor injury
# 81149                k - fatal injury
# 81150             c - possible injury
# Name: person_injury_severity, Length: 14557, dtype: object

# %%
mask_list = ['person_age', 'person_ethnicity', 'person_gender', 'person_helmet', 'person_injury_severity', 'person_drug_test_result']
