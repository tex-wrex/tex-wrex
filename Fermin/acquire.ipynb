# %% [markdown]
# # Tex Wrexs

# %% [markdown]
# ## My Imports

# %%
import pandas as pd
import numpy as np 
pd.set_option('display.max_info_columns', -1 )

# %% [markdown]
# ## Acquire the data

# %%
# pull master csv 
df = pd.read_csv('new_svcs.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    crash_id $1000_damage_to_any_one_person's_property active_school_zone_flag
# 0  16189632                                        No                      NO  \
# 1  16203470                                        No                      NO
# 2  16191458                                       Yes                      NO
# 3  16192023                                       Yes                      NO
# 4  16196720                                        No                      NO
#
#   adjusted_average_daily_traffic_amount
# 0                               no data  \
# 1                               no data
# 2                               no data
# 3                               no data
# 4                               no data
#
#   adjusted_percentage_of_average_daily_traffic_for_trucks
# 0                                            no data       \
# 1                                            no data
# 2                                            no data
# ...

# %%
mask_list = ['crash_id','person_age', 'charge', 'person_ethnicity','financial_responsibility_type','crash_date', 'day_of_week', 'person_gender',
             'person_helmet','driver_license_class','driver_license_endorsements','driver_drug_test_result', 'driver_license_state',
             'driver_license_type','person_injury_severity']

# %%
# Commented it out so dupolicate csv were not created.
df[mask_list].to_csv('person_data_info.csv',index=False)

# %%
# Here when i am all done with my analysis i will come back and turn this item into a function

# my import for my functions
import pandas as pd 
import numpy as np 
import os

def acquire():

    '''
    This is the function that acquires the data from the csv file and returns it as a dataframe. 
    
    '''

# %%
(df.person_injury_severity == 'none').sum()
# Out:
# 0

# %%
df.person_injury_severity.value_counts()
# Out:
# person_injury_severity
# B - SUSPECTED MINOR INJURY      5578
# A - SUSPECTED SERIOUS INJURY    4016
# C - POSSIBLE INJURY             2569
# N - NOT INJURED                 1162
# K - FATAL INJURY                 849
# 99 - UNKNOWN                     374
# Name: count, dtype: int64

# %% [markdown]
#     We will complete the analysis in the next notebook named prepare.
