# %%
import pandas as pd

# %%
# df_0 = pd.read_csv('prepped_svc.csv')
# df_1 = pd.read_csv('vehicle.csv').drop(columns='person_injury_severity')

# %%
# for cols in df_1.columns:
#     if df_1[cols].dtype == 'object':
#         df_1[cols]= df_1[cols].str.lower()

# %%
# df = df_0.merge(df_1, left_on='crash_id', right_on='crash_id', how='left')

# %%
# df.drop(columns='Unnamed: 0', inplace= True)

# %%
# df.to_csv('master_modeling_csv.csv')

# %%
url ='https://docs.google.com/spreadsheets/d/1jKNSokzayWWk-1_mcd-DikV9B_POOLHfuOCzV-AkI5Y/export?format=csv'
df = pd.read_csv(url)

# %%
url_2 = 'https://docs.google.com/spreadsheets/d/1dkvQy61WjfB769biDp7JQPXvrEHqPuofFUIlIWVo64I/export?format=csv'

# %%
df_1 = pd.read_csv(url_2)

# %%
merged_df = df.merge(df_1, left_on='crash_id', right_on='crash_id', how='left')

# %%
# merged_df.to_csv('motocycle_data.csv')

# %%
import os

# %%
def acquire_motocycle_data():
    if os.path.exists('motocycle_data.csv'):
        df = pd.read_csv('motocycle_data.csv')
        return df
    else:
        url ='https://docs.google.com/spreadsheets/d/1jKNSokzayWWk-1_mcd-DikV9B_POOLHfuOCzV-AkI5Y/export?format=csv'
        df = pd.read_csv(url)
        url_2 = 'https://docs.google.com/spreadsheets/d/1dkvQy61WjfB769biDp7JQPXvrEHqPuofFUIlIWVo64I/export?format=csv'
        df_1 = pd.read_csv(url_2)
        merged_df = df.merge(df_1, left_on='crash_id', right_on='crash_id', how='left')
        merged_df.to_csv('motocycle_data.csv',index=False)

        return merged_df

# %%
test = acquire_motocycle_data()

# %%
test
# Out:
#          crash_id  person_age                              charge
# 0      16189632.0        37.0  operate unregistered motor vehicle  \
# 1      16203470.0        30.0                no class "m" license
# 2      16192023.0        21.0                          no charges
# 3      16196720.0        18.0      no driver license no insurance
# 4      16189103.0        28.0                          no charges
# ...           ...         ...                                 ...
# 14179  19321499.0        49.0                          no charges
# 14180  19323296.0        33.0                          no charges
# 14181  19327850.0        35.0                          no charges
# 14182  19330330.0        42.0        fail to drive in single lane
# 14183  19332955.0        49.0                          no charges
#
#       person_ethnicity  crash_date day_of_week person_gender
# 0            w - white  2018-01-01      monday      1 - male  \
# 1         h - hispanic  2018-01-04    thursday      1 - male
# 2            w - white  2018-01-05      friday      1 - male
# 3         h - hispanic  2018-01-05      friday      1 - male
# 4            w - white  2018-01-06    saturday      1 - male
# ...                ...         ...         ...           ...
# 14179        w - white  2022-12-31    saturday    2 - female
# 14180        w - white  2022-12-31    saturday      1 - male
# 14181        w - white  2022-12-31    saturday      1 - male
# 14182        b - black  2022-12-31    saturday    2 - female
# 14183        w - white  2022-12-31    saturday      1 - male
#
#                person_helmet driver_license_class  has_motocycle_endorsment
# 0               1 - not worn          c - class c                         0  \
# 1      3 - worn, not damaged          c - class c                         0
# 2          2 - worn, damaged          c - class c                         0
# 3               1 - not worn       5 - unlicensed                         0
# 4      3 - worn, not damaged   cm - class c and m                         1
# ...                      ...                  ...                       ...
# 14179           1 - not worn   cm - class c and m                         1
# 14180           1 - not worn   cm - class c and m                         1
# 14181   4 - worn, unk damage   cm - class c and m                         1
# 14182   4 - worn, unk damage   cm - class c and m                         1
# 14183  3 - worn, not damaged   cm - class c and m                         1
#
#        ...                               vehicle_model_name_x
# 0      ...  other (explain in narrative) (other (explain i...  \
# 1      ...                                  gsx-r600 (suzuki)
# 2      ...                                     yzfr6 (yamaha)
# 3      ...                                     rz500 (yamaha)
# 4      ...                             fxdf (harley-davidson)
# ...    ...                                                ...
# 14179  ...                                   xvs1100 (yamaha)
# 14180  ...                                   kx250 (kawasaki)
# 14181  ...                                      cr250 (honda)
# 14182  ...                                     cbr650 (honda)
# 14183  ...                              flt (harley-davidson)
#
#       vehicle_model_year_x license_plate_state_y vehicle_body_style_y
# 0                      NaN            TX - TEXAS      MC - MOTORCYCLE  \
# 1                   2004.0            TX - TEXAS      MC - MOTORCYCLE
# 2                   2017.0            TX - TEXAS      MC - MOTORCYCLE
# 3                   2002.0            TX - TEXAS      MC - MOTORCYCLE
# 4                   2009.0            TX - TEXAS      MC - MOTORCYCLE
# ...                    ...                   ...                  ...
# 14179               2013.0            TX - TEXAS      MC - MOTORCYCLE
# 14180               2019.0            TX - TEXAS      MC - MOTORCYCLE
# 14181               2016.0            TX - TEXAS      MC - MOTORCYCLE
# 14182               2016.0            TX - TEXAS      MC - MOTORCYCLE
# 14183               2022.0            TX - TEXAS      MC - MOTORCYCLE
#
#           vehicle_color_y             vehicle_defect_1_y
# 0              BLU - BLUE                        no data  \
# 1              GRY - GRAY                        no data
# 2              BLU - BLUE                        no data
# 3              BLU - BLUE                        no data
# 4             BLK - BLACK                        no data
# ...                   ...                            ...
# 14179         BLK - BLACK                        no data
# 14180         GRN - GREEN  5 - DEFECTIVE OR NO HEADLAMPS
# 14181         BLK - BLACK                        no data
# 14182  MUL - MULTICOLORED                        no data
# 14183         BLK - BLACK                        no data
#
#                      vehicle_make_y
# 0      OTHER (EXPLAIN IN NARRATIVE)  \
# 1                            SUZUKI
# 2                            YAMAHA
# 3                            YAMAHA
# 4                   HARLEY-DAVIDSON
# ...                             ...
# 14179                        YAMAHA
# 14180                      KAWASAKI
# 14181                         HONDA
# 14182                         HONDA
# 14183               HARLEY-DAVIDSON
#
#                                     vehicle_model_name_y vehicle_model_year_y
# 0      OTHER (EXPLAIN IN NARRATIVE) (OTHER (EXPLAIN I...              no data  \
# 1                                      GSX-R600 (SUZUKI)                 2004
# 2                                         YZFR6 (YAMAHA)                 2017
# 3                                         RZ500 (YAMAHA)                 2002
# 4                                 FXDF (HARLEY-DAVIDSON)                 2009
# ...                                                  ...                  ...
# 14179                                   XVS1100 (YAMAHA)                 2013
# 14180                                   KX250 (KAWASAKI)                 2019
# 14181                                      CR250 (HONDA)                 2016
# 14182                                     CBR650 (HONDA)                 2016
# 14183                              FLT (HARLEY-DAVIDSON)                 2022
#
#            person_injury_severity_y
# 0      A - SUSPECTED SERIOUS INJURY
# 1        B - SUSPECTED MINOR INJURY
# 2      A - SUSPECTED SERIOUS INJURY
# 3        B - SUSPECTED MINOR INJURY
# 4        B - SUSPECTED MINOR INJURY
# ...                             ...
# 14179    B - SUSPECTED MINOR INJURY
# 14180  A - SUSPECTED SERIOUS INJURY
# 14181  A - SUSPECTED SERIOUS INJURY
# 14182    B - SUSPECTED MINOR INJURY
# 14183  A - SUSPECTED SERIOUS INJURY
#
# [14184 rows x 28 columns]

# %%
import acquire as a

# %%
thingy = a.acquire_motocycle_data()
